# %% [markdown]
# # Expanding the dataset

# %% [markdown]
# We'll try to improve the model by getting 3x more non-hit songs (around 25,000 songs), while maintaning the hit-songs (around 7,800 songs).

# %%
import numpy as np
import pandas as pd
import random
import string

# %%
df1 = pd.read_csv('../spotify_api/hot100_with_audio_features.csv')

# %%
df1
# Out:
#       year                  artist                   title  \
# 0     2000             SON BY FOUR          Purest Of Pain
# 1     2000            MARC ANTHONY          You Sang To Me
# 2     2000              FAITH HILL                 Breathe
# 3     2000          JO DEE MESSINA           Thats The Way
# 4     2000            TONI BRAXTON  Just Be A Man About It
# ...    ...                     ...                     ...
# 8083  2020                   MIGOS                   g n f
# 8084  2020  A BOOGIE WIT DA HOODIE       Might Not Give Up
# 8085  2020  A BOOGIE WIT DA HOODIE                   Stain
# 8086  2020  A BOOGIE WIT DA HOODIE               Thug Love
# 8087  2020           JUSTIN BIEBER          Come Around Me
#
#                     track_id  danceability  energy   key  loudness  mode  \
# 0     1MOqMyQ7CULmWWjovkFY5B         0.565   0.547   0.0    -7.722   1.0
# 1     2dwhMQsFeHr2S787WxqAqW         0.578   0.894  10.0    -5.420   1.0
# 2     3y4LxiYMgDl4RethdzpmNe         0.529   0.496   7.0    -9.007   1.0
# 3     296XGtH5MeGisqD3uAz6Q6         0.488   0.923   2.0    -3.697   1.0
# 4     6kD36kVRn5leDDbjXpHQY0         0.753   0.450   9.0    -6.909   1.0
# ...                      ...           ...     ...   ...       ...   ...
# 8083  6ZelF5APDN5r6XnFqcnvWR         0.904   0.627   1.0    -5.608   1.0
# 8084  0bo4hZZV4aYI4EEh1IpDNa         0.687   0.592   2.0    -6.378   1.0
# 8085  5ipk9bW6E344oWoylOOm82         0.816   0.754   8.0    -3.911   1.0
# 8086  3bhvpwuvTXpoQMI3l41NQ0         0.543   0.643   5.0    -4.707   0.0
# 8087  2o9LAypwGH4ctV0i9boo6d         0.648   0.681   2.0    -8.389   0.0
#
#       speechiness  ...  valence    tempo            type  \
# 0          0.0347  ...    0.252   75.018  audio_features
# 1          0.0296  ...    0.741  165.980  audio_features
# 2          0.0290  ...    0.278  136.859  audio_features
# 3          0.1030  ...    0.818  183.891  audio_features
# 4          0.0924  ...    0.560  109.405  audio_features
# ...           ...  ...      ...      ...             ...
# 8083       0.2220  ...    0.236  145.976  audio_features
# 8084       0.2250  ...    0.245  178.830  audio_features
# 8085       0.3880  ...    0.604  159.073  audio_features
# 8086       0.2880  ...    0.326  178.105  audio_features
# 8087       0.0378  ...    0.767  157.941  audio_features
#
#                           id                                   uri  \
# 0     1MOqMyQ7CULmWWjovkFY5B  spotify:track:1MOqMyQ7CULmWWjovkFY5B
# 1     2dwhMQsFeHr2S787WxqAqW  spotify:track:2dwhMQsFeHr2S787WxqAqW
# 2     3y4LxiYMgDl4RethdzpmNe  spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3     296XGtH5MeGisqD3uAz6Q6  spotify:track:296XGtH5MeGisqD3uAz6Q6
# 4     6kD36kVRn5leDDbjXpHQY0  spotify:track:6kD36kVRn5leDDbjXpHQY0
# ...                      ...                                   ...
# 8083  6ZelF5APDN5r6XnFqcnvWR  spotify:track:6ZelF5APDN5r6XnFqcnvWR
# 8084  0bo4hZZV4aYI4EEh1IpDNa  spotify:track:0bo4hZZV4aYI4EEh1IpDNa
# 8085  5ipk9bW6E344oWoylOOm82  spotify:track:5ipk9bW6E344oWoylOOm82
# 8086  3bhvpwuvTXpoQMI3l41NQ0  spotify:track:3bhvpwuvTXpoQMI3l41NQ0
# 8087  2o9LAypwGH4ctV0i9boo6d  spotify:track:2o9LAypwGH4ctV0i9boo6d
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1MOqMyQ7CULm...
# 1     https://api.spotify.com/v1/tracks/2dwhMQsFeHr2...
# 2     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3     https://api.spotify.com/v1/tracks/296XGtH5MeGi...
# 4     https://api.spotify.com/v1/tracks/6kD36kVRn5le...
# ...                                                 ...
# 8083  https://api.spotify.com/v1/tracks/6ZelF5APDN5r...
# 8084  https://api.spotify.com/v1/tracks/0bo4hZZV4aYI...
# 8085  https://api.spotify.com/v1/tracks/5ipk9bW6E344...
# 8086  https://api.spotify.com/v1/tracks/3bhvpwuvTXpo...
# 8087  https://api.spotify.com/v1/tracks/2o9LAypwGH4c...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1MOq...    209320.0
# 1     https://api.spotify.com/v1/audio-analysis/2dwh...    347107.0
# 2     https://api.spotify.com/v1/audio-analysis/3y4L...    250547.0
# 3     https://api.spotify.com/v1/audio-analysis/296X...    202253.0
# 4     https://api.spotify.com/v1/audio-analysis/6kD3...    288933.0
# ...                                                 ...         ...
# 8083  https://api.spotify.com/v1/audio-analysis/6Zel...    224243.0
# 8084  https://api.spotify.com/v1/audio-analysis/0bo4...    225266.0
# 8085  https://api.spotify.com/v1/audio-analysis/5ipk...    175128.0
# 8086  https://api.spotify.com/v1/audio-analysis/3bhv...    181744.0
# 8087  https://api.spotify.com/v1/audio-analysis/2o9L...    200773.0
#
#      time_signature success
# 0               4.0     1.0
# 1               4.0     1.0
# 2               4.0     1.0
# 3               4.0     1.0
# 4               4.0     1.0
# ...             ...     ...
# 8083            4.0     1.0
# 8084            4.0     1.0
# 8085            4.0     1.0
# 8086            4.0     1.0
# 8087            4.0     1.0
#
# [8088 rows x 23 columns]

# %%
df1.drop_duplicates(subset=['id'], inplace=True)

# %%
df1.shape
# Out:
# (7858, 23)

# %%
df1.drop(['year','artist', 'title', 'track_id'], axis=1, inplace=True)

# %%
df2 = pd.read_csv('../spotify_api/25682_random_songs_with_audio_features.csv')

# %%
df2
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.5650  0.1450   6.0   -19.132   1.0       0.7200        0.8840
# 1            0.1760  0.0624   9.0   -26.590   0.0       0.0523        0.9880
# 2            0.7180  0.5060  11.0   -12.246   1.0       0.9410        0.7320
# 3            0.7490  0.6930   6.0    -9.252   0.0       0.2910        0.2820
# 4            0.4160  0.8710   0.0    -6.306   1.0       0.0793        0.0317
# ...             ...     ...   ...       ...   ...          ...           ...
# 25677        0.2080  0.0436   8.0   -24.426   1.0       0.0345        0.9640
# 25678        0.0871  0.4030   1.0   -27.037   1.0       0.2680        0.9340
# 25679        0.2810  0.1780   0.0   -28.276   0.0       0.0856        0.5180
# 25680        0.3830  0.1230   4.0   -18.018   0.0       0.0451        0.9700
# 25681        0.7180  0.1390  11.0   -20.712   0.0       0.9490        0.9470
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.9350   0.5040   75.901  audio_features
# 1              0.971000    0.6620   0.1890  171.450  audio_features
# 2              0.000000    0.1860   0.5380   99.652  audio_features
# 3              0.793000    0.1990   0.5530  174.143  audio_features
# 4              0.000024    0.9760   0.6670  102.308  audio_features
# ...                 ...       ...      ...      ...             ...
# 25677          0.876000    0.0807   0.0372   81.713  audio_features
# 25678          0.624000    0.1330   0.2470   83.861  audio_features
# 25679          0.000128    0.2640   0.4240  130.658  audio_features
# 25680          0.000000    0.2120   0.6820   77.449  audio_features
# 25681          0.000000    0.2040   0.5980  120.855  audio_features
#
#                            id                                   uri  \
# 0      6E4XJoq6iDeNertmZtANcM  spotify:track:6E4XJoq6iDeNertmZtANcM
# 1      07zvM3ZiP5Y8GdRWbZ7oNm  spotify:track:07zvM3ZiP5Y8GdRWbZ7oNm
# 2      0x5QddVlDUkVkSa1X9R0F6  spotify:track:0x5QddVlDUkVkSa1X9R0F6
# 3      2cbLkWOlNWvkkv4FnIKEbq  spotify:track:2cbLkWOlNWvkkv4FnIKEbq
# 4      1G3xPkCv4SLhZahEomh7QN  spotify:track:1G3xPkCv4SLhZahEomh7QN
# ...                       ...                                   ...
# 25677  7CZbuznOPDhScMmCBk7uBO  spotify:track:7CZbuznOPDhScMmCBk7uBO
# 25678  5EJKvxoUymEW3wmbJ1GoEF  spotify:track:5EJKvxoUymEW3wmbJ1GoEF
# 25679  1tzc7FS2RoO8ywUIDtVTT8  spotify:track:1tzc7FS2RoO8ywUIDtVTT8
# 25680  5jeZEby2UbZ68tIJrdOn5c  spotify:track:5jeZEby2UbZ68tIJrdOn5c
# 25681  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6E4XJoq6iDeN...
# 1      https://api.spotify.com/v1/tracks/07zvM3ZiP5Y8...
# 2      https://api.spotify.com/v1/tracks/0x5QddVlDUkV...
# 3      https://api.spotify.com/v1/tracks/2cbLkWOlNWvk...
# 4      https://api.spotify.com/v1/tracks/1G3xPkCv4SLh...
# ...                                                  ...
# 25677  https://api.spotify.com/v1/tracks/7CZbuznOPDhS...
# 25678  https://api.spotify.com/v1/tracks/5EJKvxoUymEW...
# 25679  https://api.spotify.com/v1/tracks/1tzc7FS2RoO8...
# 25680  https://api.spotify.com/v1/tracks/5jeZEby2UbZ6...
# 25681  https://api.spotify.com/v1/tracks/331BqvDc63kv...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6E4X...     287360.0
# 1      https://api.spotify.com/v1/audio-analysis/07zv...     120226.0
# 2      https://api.spotify.com/v1/audio-analysis/0x5Q...     131114.0
# 3      https://api.spotify.com/v1/audio-analysis/2cbL...     302453.0
# 4      https://api.spotify.com/v1/audio-analysis/1G3x...     469294.0
# ...                                                  ...          ...
# 25677  https://api.spotify.com/v1/audio-analysis/7CZb...     179693.0
# 25678  https://api.spotify.com/v1/audio-analysis/5EJK...     214901.0
# 25679  https://api.spotify.com/v1/audio-analysis/1tzc...      74813.0
# 25680  https://api.spotify.com/v1/audio-analysis/5jeZ...     731012.0
# 25681  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
#
#        time_signature  success
# 0                 3.0      0.0
# 1                 5.0      0.0
# 2                 4.0      0.0
# 3                 4.0      0.0
# 4                 4.0      0.0
# ...               ...      ...
# 25677             4.0      0.0
# 25678             4.0      0.0
# 25679             4.0      0.0
# 25680             3.0      0.0
# 25681             4.0      0.0
#
# [25682 rows x 19 columns]

# %%
df2.drop_duplicates(subset=['id'], inplace=True)

# %%
df2.shape
# Out:
# (25682, 19)

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.5650  0.5470   0.0    -7.722   1.0       0.0347        0.5790
# 1            0.5780  0.8940  10.0    -5.420   1.0       0.0296        0.0103
# 2            0.5290  0.4960   7.0    -9.007   1.0       0.0290        0.1730
# 3            0.4880  0.9230   2.0    -3.697   1.0       0.1030        0.1290
# 4            0.7530  0.4500   9.0    -6.909   1.0       0.0924        0.2740
# ...             ...     ...   ...       ...   ...          ...           ...
# 33535        0.2080  0.0436   8.0   -24.426   1.0       0.0345        0.9640
# 33536        0.0871  0.4030   1.0   -27.037   1.0       0.2680        0.9340
# 33537        0.2810  0.1780   0.0   -28.276   0.0       0.0856        0.5180
# 33538        0.3830  0.1230   4.0   -18.018   0.0       0.0451        0.9700
# 33539        0.7180  0.1390  11.0   -20.712   0.0       0.9490        0.9470
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.1940   0.2520   75.018  audio_features
# 1              0.000003    0.2160   0.7410  165.980  audio_features
# 2              0.000000    0.2510   0.2780  136.859  audio_features
# 3              0.000000    0.1580   0.8180  183.891  audio_features
# 4              0.000002    0.3210   0.5600  109.405  audio_features
# ...                 ...       ...      ...      ...             ...
# 33535          0.876000    0.0807   0.0372   81.713  audio_features
# 33536          0.624000    0.1330   0.2470   83.861  audio_features
# 33537          0.000128    0.2640   0.4240  130.658  audio_features
# 33538          0.000000    0.2120   0.6820   77.449  audio_features
# 33539          0.000000    0.2040   0.5980  120.855  audio_features
#
#                            id                                   uri  \
# 0      1MOqMyQ7CULmWWjovkFY5B  spotify:track:1MOqMyQ7CULmWWjovkFY5B
# 1      2dwhMQsFeHr2S787WxqAqW  spotify:track:2dwhMQsFeHr2S787WxqAqW
# 2      3y4LxiYMgDl4RethdzpmNe  spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3      296XGtH5MeGisqD3uAz6Q6  spotify:track:296XGtH5MeGisqD3uAz6Q6
# 4      6kD36kVRn5leDDbjXpHQY0  spotify:track:6kD36kVRn5leDDbjXpHQY0
# ...                       ...                                   ...
# 33535  7CZbuznOPDhScMmCBk7uBO  spotify:track:7CZbuznOPDhScMmCBk7uBO
# 33536  5EJKvxoUymEW3wmbJ1GoEF  spotify:track:5EJKvxoUymEW3wmbJ1GoEF
# 33537  1tzc7FS2RoO8ywUIDtVTT8  spotify:track:1tzc7FS2RoO8ywUIDtVTT8
# 33538  5jeZEby2UbZ68tIJrdOn5c  spotify:track:5jeZEby2UbZ68tIJrdOn5c
# 33539  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/1MOqMyQ7CULm...
# 1      https://api.spotify.com/v1/tracks/2dwhMQsFeHr2...
# 2      https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3      https://api.spotify.com/v1/tracks/296XGtH5MeGi...
# 4      https://api.spotify.com/v1/tracks/6kD36kVRn5le...
# ...                                                  ...
# 33535  https://api.spotify.com/v1/tracks/7CZbuznOPDhS...
# 33536  https://api.spotify.com/v1/tracks/5EJKvxoUymEW...
# 33537  https://api.spotify.com/v1/tracks/1tzc7FS2RoO8...
# 33538  https://api.spotify.com/v1/tracks/5jeZEby2UbZ6...
# 33539  https://api.spotify.com/v1/tracks/331BqvDc63kv...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/1MOq...     209320.0
# 1      https://api.spotify.com/v1/audio-analysis/2dwh...     347107.0
# 2      https://api.spotify.com/v1/audio-analysis/3y4L...     250547.0
# 3      https://api.spotify.com/v1/audio-analysis/296X...     202253.0
# 4      https://api.spotify.com/v1/audio-analysis/6kD3...     288933.0
# ...                                                  ...          ...
# 33535  https://api.spotify.com/v1/audio-analysis/7CZb...     179693.0
# 33536  https://api.spotify.com/v1/audio-analysis/5EJK...     214901.0
# 33537  https://api.spotify.com/v1/audio-analysis/1tzc...      74813.0
# 33538  https://api.spotify.com/v1/audio-analysis/5jeZ...     731012.0
# 33539  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
#
#        time_signature  success
# 0                 4.0      1.0
# 1                 4.0      1.0
# 2                 4.0      1.0
# 3                 4.0      1.0
# 4                 4.0      1.0
# ...               ...      ...
# 33535             4.0      0.0
# 33536             4.0      0.0
# 33537             4.0      0.0
# 33538             3.0      0.0
# 33539             4.0      0.0
#
# [33540 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# danceability        1
# energy              1
# key                 1
# loudness            1
# mode                1
# speechiness         1
# acousticness        1
# instrumentalness    1
# liveness            1
# valence             1
# tempo               1
# type                1
# id                  1
# uri                 1
# track_href          1
# analysis_url        1
# duration_ms         1
# time_signature      1
# success             0
# dtype: int64

# %%
df[df['id'].isnull()]
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 5515           NaN     NaN  NaN       NaN   NaN          NaN           NaN
#
#       instrumentalness  liveness  valence  tempo type   id  uri track_href  \
# 5515               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
#
#      analysis_url  duration_ms  time_signature  success
# 5515          NaN          NaN             NaN      1.0

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.5650  0.5470   0.0    -7.722   1.0       0.0347        0.5790
# 1            0.5780  0.8940  10.0    -5.420   1.0       0.0296        0.0103
# 2            0.5290  0.4960   7.0    -9.007   1.0       0.0290        0.1730
# 3            0.4880  0.9230   2.0    -3.697   1.0       0.1030        0.1290
# 4            0.7530  0.4500   9.0    -6.909   1.0       0.0924        0.2740
# ...             ...     ...   ...       ...   ...          ...           ...
# 33534        0.2080  0.0436   8.0   -24.426   1.0       0.0345        0.9640
# 33535        0.0871  0.4030   1.0   -27.037   1.0       0.2680        0.9340
# 33536        0.2810  0.1780   0.0   -28.276   0.0       0.0856        0.5180
# 33537        0.3830  0.1230   4.0   -18.018   0.0       0.0451        0.9700
# 33538        0.7180  0.1390  11.0   -20.712   0.0       0.9490        0.9470
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.1940   0.2520   75.018  audio_features
# 1              0.000003    0.2160   0.7410  165.980  audio_features
# 2              0.000000    0.2510   0.2780  136.859  audio_features
# 3              0.000000    0.1580   0.8180  183.891  audio_features
# 4              0.000002    0.3210   0.5600  109.405  audio_features
# ...                 ...       ...      ...      ...             ...
# 33534          0.876000    0.0807   0.0372   81.713  audio_features
# 33535          0.624000    0.1330   0.2470   83.861  audio_features
# 33536          0.000128    0.2640   0.4240  130.658  audio_features
# 33537          0.000000    0.2120   0.6820   77.449  audio_features
# 33538          0.000000    0.2040   0.5980  120.855  audio_features
#
#                            id                                   uri  \
# 0      1MOqMyQ7CULmWWjovkFY5B  spotify:track:1MOqMyQ7CULmWWjovkFY5B
# 1      2dwhMQsFeHr2S787WxqAqW  spotify:track:2dwhMQsFeHr2S787WxqAqW
# 2      3y4LxiYMgDl4RethdzpmNe  spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3      296XGtH5MeGisqD3uAz6Q6  spotify:track:296XGtH5MeGisqD3uAz6Q6
# 4      6kD36kVRn5leDDbjXpHQY0  spotify:track:6kD36kVRn5leDDbjXpHQY0
# ...                       ...                                   ...
# 33534  7CZbuznOPDhScMmCBk7uBO  spotify:track:7CZbuznOPDhScMmCBk7uBO
# 33535  5EJKvxoUymEW3wmbJ1GoEF  spotify:track:5EJKvxoUymEW3wmbJ1GoEF
# 33536  1tzc7FS2RoO8ywUIDtVTT8  spotify:track:1tzc7FS2RoO8ywUIDtVTT8
# 33537  5jeZEby2UbZ68tIJrdOn5c  spotify:track:5jeZEby2UbZ68tIJrdOn5c
# 33538  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/1MOqMyQ7CULm...
# 1      https://api.spotify.com/v1/tracks/2dwhMQsFeHr2...
# 2      https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3      https://api.spotify.com/v1/tracks/296XGtH5MeGi...
# 4      https://api.spotify.com/v1/tracks/6kD36kVRn5le...
# ...                                                  ...
# 33534  https://api.spotify.com/v1/tracks/7CZbuznOPDhS...
# 33535  https://api.spotify.com/v1/tracks/5EJKvxoUymEW...
# 33536  https://api.spotify.com/v1/tracks/1tzc7FS2RoO8...
# 33537  https://api.spotify.com/v1/tracks/5jeZEby2UbZ6...
# 33538  https://api.spotify.com/v1/tracks/331BqvDc63kv...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/1MOq...     209320.0
# 1      https://api.spotify.com/v1/audio-analysis/2dwh...     347107.0
# 2      https://api.spotify.com/v1/audio-analysis/3y4L...     250547.0
# 3      https://api.spotify.com/v1/audio-analysis/296X...     202253.0
# 4      https://api.spotify.com/v1/audio-analysis/6kD3...     288933.0
# ...                                                  ...          ...
# 33534  https://api.spotify.com/v1/audio-analysis/7CZb...     179693.0
# 33535  https://api.spotify.com/v1/audio-analysis/5EJK...     214901.0
# 33536  https://api.spotify.com/v1/audio-analysis/1tzc...      74813.0
# 33537  https://api.spotify.com/v1/audio-analysis/5jeZ...     731012.0
# 33538  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
#
#        time_signature  success
# 0                 4.0      1.0
# 1                 4.0      1.0
# 2                 4.0      1.0
# 3                 4.0      1.0
# 4                 4.0      1.0
# ...               ...      ...
# 33534             4.0      0.0
# 33535             4.0      0.0
# 33536             4.0      0.0
# 33537             3.0      0.0
# 33538             4.0      0.0
#
# [33539 rows x 19 columns]

# %%
df[df.duplicated(subset=['id'])]
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8140          0.348   0.717  4.0    -5.634   1.0       0.0882         0.311
# 12555         0.508   0.256  7.0   -12.060   1.0       0.0329         0.846
# 25050         0.701   0.931  8.0    -0.945   0.0       0.2430         0.239
#
#        instrumentalness  liveness  valence   tempo            type  \
# 8140                0.0    0.0786    0.280  66.210  audio_features
# 12555               0.0    0.8860    0.360  76.898  audio_features
# 25050               0.0    0.1940    0.362  79.996  audio_features
#
#                            id                                   uri  \
# 8140   07rhyW77lp2bGv8EQoZy6k  spotify:track:07rhyW77lp2bGv8EQoZy6k
# 12555  2Ye8Nxea8VIiOaS2X24xad  spotify:track:2Ye8Nxea8VIiOaS2X24xad
# 25050  0dyWQoMOU9oERL6c9vxtRp  spotify:track:0dyWQoMOU9oERL6c9vxtRp
#
#                                               track_href  \
# 8140   https://api.spotify.com/v1/tracks/07rhyW77lp2b...
# 12555  https://api.spotify.com/v1/tracks/2Ye8Nxea8VIi...
# 25050  https://api.spotify.com/v1/tracks/0dyWQoMOU9oE...
#
#                                             analysis_url  duration_ms  \
# 8140   https://api.spotify.com/v1/audio-analysis/07rh...     416778.0
# 12555  https://api.spotify.com/v1/audio-analysis/2Ye8...     303400.0
# 25050  https://api.spotify.com/v1/audio-analysis/0dyW...     241587.0
#
#        time_signature  success
# 8140              4.0      0.0
# 12555             4.0      0.0
# 25050             4.0      0.0

# %%
df.drop_duplicates(subset=['id'], inplace=True)

# %%
df[df['success']==1.0].shape
# Out:
# (7857, 19)

# %%
df[df['success']==0.0].shape
# Out:
# (25679, 19)

# %%
df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  33536.000000  33536.000000  33536.000000  33536.000000  33536.000000
# mean       0.589530      0.465480      5.314349    -12.953093      0.659590
# std        0.187247      0.270191      3.549401      7.278107      0.473854
# min        0.000000      0.000000      0.000000    -60.000000      0.000000
# 25%        0.497000      0.244000      2.000000    -18.205000      0.000000
# 50%        0.639000      0.426000      5.000000    -11.822500      1.000000
# 75%        0.715000      0.700000      9.000000     -6.553000      1.000000
# max        0.986000      1.000000     11.000000      3.535000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  33536.000000  33536.000000      33536.000000  33536.000000
# mean       0.378576      0.438698          0.159665      0.232129
# std        0.403334      0.341928          0.329557      0.190496
# min        0.000000      0.000000          0.000000      0.000000
# 25%        0.042100      0.092300          0.000000      0.109000
# 50%        0.103000      0.417000          0.000000      0.156000
# 75%        0.924000      0.743000          0.003513      0.304000
# max        0.971000      0.996000          1.000000      1.000000
#
#            valence         tempo   duration_ms  time_signature       success
# count  33536.00000  33536.000000  3.353600e+04    33536.000000  33536.000000
# mean       0.47225    113.457698  2.032486e+05        3.686039      0.234286
# std        0.25087     33.788113  1.620152e+05        0.916058      0.423558
# min        0.00000      0.000000  3.137000e+03        0.000000      0.000000
# 25%        0.28700     89.302500  1.236045e+05        3.000000      0.000000
# 50%        0.47300    112.930000  1.880800e+05        4.000000      0.000000
# 75%        0.66100    132.994250  2.416832e+05        4.000000      0.000000
# max        1.00000    247.994000  4.354000e+06        5.000000      1.000000

# %%
df[df['success']==1.0].shape
# Out:
# (7857, 19)

# %%
df[df['success']==0.0].shape
# Out:
# (25679, 19)

# %%
df.to_csv('hot_plus_random_expanded.csv', encoding='utf-8', index=False)
