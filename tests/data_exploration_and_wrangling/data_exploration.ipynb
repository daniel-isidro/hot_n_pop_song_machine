# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('100_hit_100_non_hit_songs.csv')

# %%
df.head()
# Out:
#                  track_id  danceability  energy  key  loudness  mode  \
# 0  2YpeDb67231RjR0MgVLzsG         0.878   0.619    6    -5.560     1
# 1  3KkXRkHbMCARz0aVfEt68P         0.760   0.479    2    -5.574     1
# 2  5p7ujcrUXASCNwRaWNHR1C         0.752   0.488    6    -7.050     1
# 3  2Fxmhks0bxGSBdJ92vM42m         0.701   0.425    7   -10.965     1
# 4  7xQAfvXzm3AkraOtGPWIZg         0.829   0.539   11    -7.359     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1020        0.0533          0.000000    0.1130    0.639  136.041
# 1       0.0466        0.5560          0.000000    0.0703    0.913   89.911
# 2       0.0705        0.2970          0.000009    0.0936    0.533  136.041
# 3       0.3750        0.3280          0.130000    0.1000    0.562  135.128
# 4       0.2080        0.1360          0.000002    0.1030    0.388   99.960
#
#    duration_ms  time_signature  success
# 0       157067               4      1.0
# 1       158040               4      1.0
# 2       201661               4      1.0
# 3       194088               4      1.0
# 4       149547               4      1.0

# %%
df.shape
# Out:
# (200, 15)

# %% [markdown]
# I see there are 13 audio features I'm interested in: danceability	energy	key	loudness	mode	speechiness	acousticness	instrumentalness	liveness	valence	tempo	duration_ms	time_signature.
# The 'success' column is the target

# %%
sns.set()

# %%
sns.pairplot(df, hue='success', height=3);

# %%
sns.set(rc={'figure.figsize':(15,14)})
sns.heatmap(df.corr(), annot = True, fmt='.1g', square=True);

# %%
grids = sns.PairGrid(df)
grids.map_diag(sns.kdeplot, lw=3, legend=False)
grids.map_upper(sns.kdeplot)
grids.map_lower(plt.scatter);
