# %%
import numpy as np
import pandas as pd
import json
import os
import random
import string
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

pd.set_option("max_rows", 10)

# %%
# Reading Spotify web API credentials from settings.env hidden file

with open('settings.env') as f:
    env_vars = json.loads(f.read())

# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = env_vars['SPOTIPY_CLIENT_ID']
os.environ['SPOTIPY_CLIENT_SECRET'] = env_vars['SPOTIPY_CLIENT_SECRET']

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
# Getting 8100 random songs to balance the hit/not-hit songs datasets
# Year range same as selected for hit songs: 2000-2020

track_id_list = []

for i in range(0,8100):
    search = sp.search(q=random.choice(string.ascii_letters + string.digits) + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    track_id = search['tracks']['items'][0]['id']
    track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 8100

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
df
# Out:
#                     track_id
# 0     608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ
# ...                      ...
# 8095  6YXG34IWbilypPwjBTOrUC
# 8096  08cXy6KUizaAelYXtcew3w
# 8097  6Hmj7SrLRbreLVfVS7mV1S
# 8098  30AW1wD8qK1Bqw3Z44xs3f
# 8099  6U9aiT7cvmOL4hRHnHISUx
#
# [8100 rows x 1 columns]

# %%
# No NaN's

df[df['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 1837 duplicates

df[df.duplicated()].shape
# Out:
# (1837, 1)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                     track_id
# 0     608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ
# ...                      ...
# 8092  6MBPfkgkEpivlswUuTMdj0
# 8095  6YXG34IWbilypPwjBTOrUC
# 8096  08cXy6KUizaAelYXtcew3w
# 8098  30AW1wD8qK1Bqw3Z44xs3f
# 8099  6U9aiT7cvmOL4hRHnHISUx
#
# [6263 rows x 1 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.to_csv('6262_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
# Getting 4000 more random songs to balance the hit/not-hit songs datasets
# Year range same as selected for hit songs: 2000-2020

track_id_list = []

for i in range(0,4000):
    search = sp.search(q=random.choice(string.ascii_letters + string.digits) + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    track_id = search['tracks']['items'][0]['id']
    track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 4000

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
df
# Out:
#                     track_id
# 0     4ek3pPdfvIbPxynmlisI0k
# 1     2aibwv5hGXSgw7Yru8IYTO
# 2     3LUWWox8YYykohBbHUrrxd
# 3     1ckLp8lCl8LipXI0ypX72m
# 4     3fBbfrWZUuWWrMQXFISr7N
# ...                      ...
# 3995  6e7hIhOLH9zvb3zP5O5gt0
# 3996  0CLibGiioSuyci4NSbYi9q
# 3997  6otiaV2fagE3s8IvP6WkwG
# 3998  6mifT2myhvgBlPpf8kyHT7
# 3999  3rGxEDA6CqMweXzyhmF4Y0
#
# [4000 rows x 1 columns]

# %%
# No NaN's

df[df['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 501 duplicates

df[df.duplicated()].shape
# Out:
# (501, 1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                     track_id
# 0     4ek3pPdfvIbPxynmlisI0k
# 1     2aibwv5hGXSgw7Yru8IYTO
# 2     3LUWWox8YYykohBbHUrrxd
# 3     1ckLp8lCl8LipXI0ypX72m
# 4     3fBbfrWZUuWWrMQXFISr7N
# ...                      ...
# 3494  6V81K1OcvYgHEnCA6A2Qx9
# 3495  4D1eVq5AUILwjg3tAe7o6M
# 3496  6otiaV2fagE3s8IvP6WkwG
# 3497  6mifT2myhvgBlPpf8kyHT7
# 3498  3rGxEDA6CqMweXzyhmF4Y0
#
# [3499 rows x 1 columns]

# %%
df.to_csv('3499_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
df = pd.concat(map(pd.read_csv, 
                   ['6262_random_songs_2000-2020.csv',
                    '3499_random_songs_2000-2020.csv'], 
                  ), ignore_index=True)

# %%
df
# Out:
#                     track_id
# 0     608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ
# ...                      ...
# 9757  6V81K1OcvYgHEnCA6A2Qx9
# 9758  4D1eVq5AUILwjg3tAe7o6M
# 9759  6otiaV2fagE3s8IvP6WkwG
# 9760  6mifT2myhvgBlPpf8kyHT7
# 9761  3rGxEDA6CqMweXzyhmF4Y0
#
# [9762 rows x 1 columns]

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                     track_id
# 0     608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ
# ...                      ...
# 8384  3h1ghsF7s2VplSMp9pcTTr
# 8385  2GQEM9JuHu30sGFvRYeCxz
# 8386  4aceMabp5rzZYoKKXsUffr
# 8387  6mifT2myhvgBlPpf8kyHT7
# 8388  3rGxEDA6CqMweXzyhmF4Y0
#
# [8389 rows x 1 columns]

# %%
df.to_csv('8300_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
# Get audio_features

audio = [sp.audio_features(x) for x in df['track_id']]

# %%
audio_df = pd.DataFrame()

empty_row = {'danceability': np.nan,
 'energy': np.nan,
 'key': np.nan,
 'loudness': np.nan,
 'mode': np.nan,
 'speechiness': np.nan,
 'acousticness': np.nan,
 'instrumentalness': np.nan,
 'liveness': np.nan,
 'valence': np.nan,
 'tempo': np.nan,
 'type': np.nan,
 'id': np.nan,
 'uri': np.nan,
 'track_href': np.nan,
 'analysis_url': np.nan,
 'duration_ms': np.nan,
 'time_signature': np.nan}

for i in range(0,len(df['track_id'])):
    if type(audio[i][0]) != type(None):
        audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
    else:
        audio_df = audio_df.append(pd.json_normalize(empty_row))

# %%
audio_df.isnull().sum()
# Out:
# danceability      581
# energy            581
# key               581
# loudness          581
# mode              581
#                  ...
# uri               581
# track_href        581
# analysis_url      581
# duration_ms       581
# time_signature    581
# Length: 18, dtype: int64

# %%
audio_df.shape
# Out:
# (8389, 18)

# %%
audio_df[audio_df['danceability'].isnull()]
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 40             NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 65             NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 73             NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 90             NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 99             NaN     NaN  NaN       NaN   NaN          NaN           NaN
# ...            ...     ...  ...       ...   ...          ...           ...
# 8340           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 8366           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 8367           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 8383           NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 8388           NaN     NaN  NaN       NaN   NaN          NaN           NaN
#
#       instrumentalness  liveness  valence  tempo type   id  uri track_href  \
# 40                 NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 65                 NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 73                 NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 90                 NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 99                 NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# ...                ...       ...      ...    ...  ...  ...  ...        ...
# 8340               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 8366               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 8367               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 8383               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 8388               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
#
#      analysis_url  duration_ms  time_signature
# 40            NaN          NaN             NaN
# 65            NaN          NaN             NaN
# 73            NaN          NaN             NaN
# 90            NaN          NaN             NaN
# 99            NaN          NaN             NaN
# ...           ...          ...             ...
# 8340          NaN          NaN             NaN
# 8366          NaN          NaN             NaN
# 8367          NaN          NaN             NaN
# 8383          NaN          NaN             NaN
# 8388          NaN          NaN             NaN
#
# [581 rows x 18 columns]

# %%
audio_df.dropna(inplace=True)

# %%
audio_df.reset_index(drop=True, inplace=True)
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.413   0.807  11.0    -3.499   0.0       0.3180       0.05360
# 1            0.131   0.279   0.0   -13.504   1.0       0.0379       0.70400
# 2            0.373   0.249   2.0   -23.432   0.0       0.0477       0.99500
# 3            0.751   0.672   1.0    -3.017   1.0       0.2450       0.00698
# 4            0.831   0.795   1.0    -6.186   1.0       0.2640       0.22100
# ...            ...     ...   ...       ...   ...          ...           ...
# 7803         0.569   0.840   1.0    -4.123   1.0       0.1180       0.02950
# 7804         0.187   0.191   2.0   -22.582   1.0       0.0360       0.98900
# 7805         0.867   0.477   9.0    -7.183   0.0       0.0490       0.00843
# 7806         0.419   0.532   5.0    -4.759   0.0       0.0344       0.12700
# 7807         0.328   0.144   8.0   -27.521   1.0       0.0356       0.99300
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6310    0.438  149.330  audio_features
# 1             0.002490    0.1210    0.175  179.252  audio_features
# 2             0.920000    0.1060    0.656  148.346  audio_features
# 3             0.000000    0.1720    0.340  158.087  audio_features
# 4             0.000000    0.2910    0.744  160.063  audio_features
# ...                ...       ...      ...      ...             ...
# 7803          0.000118    0.0995    0.749  183.059  audio_features
# 7804          0.877000    0.1270    0.685  190.959  audio_features
# 7805          0.175000    0.1130    0.614  124.979  audio_features
# 7806          0.000000    0.0785    0.337  184.197  audio_features
# 7807          0.882000    0.0948    0.418  109.933  audio_features
#
#                           id                                   uri  \
# 0     608a1wIsSd5KzMEqm1O7w3  spotify:track:608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M  spotify:track:33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt  spotify:track:5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp  spotify:track:4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ  spotify:track:21kOVEG3bDCVphKhXL8XmQ
# ...                      ...                                   ...
# 7803  5JWPUEov2wlX7c0jhYZpeB  spotify:track:5JWPUEov2wlX7c0jhYZpeB
# 7804  3h1ghsF7s2VplSMp9pcTTr  spotify:track:3h1ghsF7s2VplSMp9pcTTr
# 7805  2GQEM9JuHu30sGFvRYeCxz  spotify:track:2GQEM9JuHu30sGFvRYeCxz
# 7806  4aceMabp5rzZYoKKXsUffr  spotify:track:4aceMabp5rzZYoKKXsUffr
# 7807  6mifT2myhvgBlPpf8kyHT7  spotify:track:6mifT2myhvgBlPpf8kyHT7
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/608a1wIsSd5K...
# 1     https://api.spotify.com/v1/tracks/33VcQq9PLgJh...
# 2     https://api.spotify.com/v1/tracks/5mI9HJdkqtqW...
# 3     https://api.spotify.com/v1/tracks/4FDG9SHyQkxk...
# 4     https://api.spotify.com/v1/tracks/21kOVEG3bDCV...
# ...                                                 ...
# 7803  https://api.spotify.com/v1/tracks/5JWPUEov2wlX...
# 7804  https://api.spotify.com/v1/tracks/3h1ghsF7s2Vp...
# 7805  https://api.spotify.com/v1/tracks/2GQEM9JuHu30...
# 7806  https://api.spotify.com/v1/tracks/4aceMabp5rzZ...
# 7807  https://api.spotify.com/v1/tracks/6mifT2myhvgB...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/608a...     296147.0
# 1     https://api.spotify.com/v1/audio-analysis/33Vc...     201080.0
# 2     https://api.spotify.com/v1/audio-analysis/5mI9...     132000.0
# 3     https://api.spotify.com/v1/audio-analysis/4FDG...     195818.0
# 4     https://api.spotify.com/v1/audio-analysis/21kO...      96064.0
# ...                                                 ...          ...
# 7803  https://api.spotify.com/v1/audio-analysis/5JWP...     249587.0
# 7804  https://api.spotify.com/v1/audio-analysis/3h1g...     190569.0
# 7805  https://api.spotify.com/v1/audio-analysis/2GQE...     223480.0
# 7806  https://api.spotify.com/v1/audio-analysis/4ace...     218737.0
# 7807  https://api.spotify.com/v1/audio-analysis/6mif...      75573.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 7803             3.0
# 7804             3.0
# 7805             4.0
# 7806             4.0
# 7807             1.0
#
# [7808 rows x 18 columns]

# %%
audio_df['success'] = 0.0

# %%
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.413   0.807  11.0    -3.499   0.0       0.3180       0.05360
# 1            0.131   0.279   0.0   -13.504   1.0       0.0379       0.70400
# 2            0.373   0.249   2.0   -23.432   0.0       0.0477       0.99500
# 3            0.751   0.672   1.0    -3.017   1.0       0.2450       0.00698
# 4            0.831   0.795   1.0    -6.186   1.0       0.2640       0.22100
# ...            ...     ...   ...       ...   ...          ...           ...
# 7803         0.569   0.840   1.0    -4.123   1.0       0.1180       0.02950
# 7804         0.187   0.191   2.0   -22.582   1.0       0.0360       0.98900
# 7805         0.867   0.477   9.0    -7.183   0.0       0.0490       0.00843
# 7806         0.419   0.532   5.0    -4.759   0.0       0.0344       0.12700
# 7807         0.328   0.144   8.0   -27.521   1.0       0.0356       0.99300
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6310    0.438  149.330  audio_features
# 1             0.002490    0.1210    0.175  179.252  audio_features
# 2             0.920000    0.1060    0.656  148.346  audio_features
# 3             0.000000    0.1720    0.340  158.087  audio_features
# 4             0.000000    0.2910    0.744  160.063  audio_features
# ...                ...       ...      ...      ...             ...
# 7803          0.000118    0.0995    0.749  183.059  audio_features
# 7804          0.877000    0.1270    0.685  190.959  audio_features
# 7805          0.175000    0.1130    0.614  124.979  audio_features
# 7806          0.000000    0.0785    0.337  184.197  audio_features
# 7807          0.882000    0.0948    0.418  109.933  audio_features
#
#                           id                                   uri  \
# 0     608a1wIsSd5KzMEqm1O7w3  spotify:track:608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M  spotify:track:33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt  spotify:track:5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp  spotify:track:4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ  spotify:track:21kOVEG3bDCVphKhXL8XmQ
# ...                      ...                                   ...
# 7803  5JWPUEov2wlX7c0jhYZpeB  spotify:track:5JWPUEov2wlX7c0jhYZpeB
# 7804  3h1ghsF7s2VplSMp9pcTTr  spotify:track:3h1ghsF7s2VplSMp9pcTTr
# 7805  2GQEM9JuHu30sGFvRYeCxz  spotify:track:2GQEM9JuHu30sGFvRYeCxz
# 7806  4aceMabp5rzZYoKKXsUffr  spotify:track:4aceMabp5rzZYoKKXsUffr
# 7807  6mifT2myhvgBlPpf8kyHT7  spotify:track:6mifT2myhvgBlPpf8kyHT7
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/608a1wIsSd5K...
# 1     https://api.spotify.com/v1/tracks/33VcQq9PLgJh...
# 2     https://api.spotify.com/v1/tracks/5mI9HJdkqtqW...
# 3     https://api.spotify.com/v1/tracks/4FDG9SHyQkxk...
# 4     https://api.spotify.com/v1/tracks/21kOVEG3bDCV...
# ...                                                 ...
# 7803  https://api.spotify.com/v1/tracks/5JWPUEov2wlX...
# 7804  https://api.spotify.com/v1/tracks/3h1ghsF7s2Vp...
# 7805  https://api.spotify.com/v1/tracks/2GQEM9JuHu30...
# 7806  https://api.spotify.com/v1/tracks/4aceMabp5rzZ...
# 7807  https://api.spotify.com/v1/tracks/6mifT2myhvgB...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/608a...     296147.0
# 1     https://api.spotify.com/v1/audio-analysis/33Vc...     201080.0
# 2     https://api.spotify.com/v1/audio-analysis/5mI9...     132000.0
# 3     https://api.spotify.com/v1/audio-analysis/4FDG...     195818.0
# 4     https://api.spotify.com/v1/audio-analysis/21kO...      96064.0
# ...                                                 ...          ...
# 7803  https://api.spotify.com/v1/audio-analysis/5JWP...     249587.0
# 7804  https://api.spotify.com/v1/audio-analysis/3h1g...     190569.0
# 7805  https://api.spotify.com/v1/audio-analysis/2GQE...     223480.0
# 7806  https://api.spotify.com/v1/audio-analysis/4ace...     218737.0
# 7807  https://api.spotify.com/v1/audio-analysis/6mif...      75573.0
#
#       time_signature  sucess
# 0                4.0     1.0
# 1                4.0     1.0
# 2                4.0     1.0
# 3                4.0     1.0
# 4                4.0     1.0
# ...              ...     ...
# 7803             3.0     1.0
# 7804             3.0     1.0
# 7805             4.0     1.0
# 7806             4.0     1.0
# 7807             1.0     1.0
#
# [7808 rows x 19 columns]

# %%
audio_df.to_csv('7808_random_songs_with_audio_features.csv', encoding='utf-8', index=False)

# %%
# Getting 2000 more random songs to balance the hit/not-hit songs datasets
# Year range same as selected for hit songs: 2000-2020

track_id_list = []

for i in range(0,2000):
    search = sp.search(q=random.choice(string.ascii_letters + string.digits) + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    track_id = search['tracks']['items'][0]['id']
    track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 2000

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
df[df.duplicated()].shape
# Out:
# (149, 1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                     track_id
# 0     2twGKYnxAYNRQ9z9F3sQ4o
# 1     6Kn5yzAyOw3jf4Y5a6d1Oq
# 2     1YlulsUKDduOmC7WxvXYPW
# 3     3DA4SE262k6rdEtlHteNyq
# 4     6ihL9TjfRjadfEePzXXyVF
# ...                      ...
# 1846  4TTV7EcfroSLWzXRY6gLv6
# 1847  3cFHCXuBZKMJd8Q4Wt8RB3
# 1848  0KkIkfsLEJbrcIhYsCL7L5
# 1849  6NtUvEqIOgO1rRkQk6F0aE
# 1850  68JS5SFTnW5Yv9Vzw81Jf0
#
# [1851 rows x 1 columns]

# %%
# Get audio_features

audio = [sp.audio_features(x) for x in df['track_id']]

# %%
audio_df = pd.DataFrame()

empty_row = {'danceability': np.nan,
 'energy': np.nan,
 'key': np.nan,
 'loudness': np.nan,
 'mode': np.nan,
 'speechiness': np.nan,
 'acousticness': np.nan,
 'instrumentalness': np.nan,
 'liveness': np.nan,
 'valence': np.nan,
 'tempo': np.nan,
 'type': np.nan,
 'id': np.nan,
 'uri': np.nan,
 'track_href': np.nan,
 'analysis_url': np.nan,
 'duration_ms': np.nan,
 'time_signature': np.nan}

for i in range(0,len(df['track_id'])):
    if type(audio[i][0]) != type(None):
        audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
    else:
        audio_df = audio_df.append(pd.json_normalize(empty_row))

# %%
audio_df.shape
# Out:
# (1851, 18)

# %%
audio_df.dropna(inplace=True)
audio_df.reset_index(drop=True, inplace=True)
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.728   0.656   6.0    -5.652   1.0       0.4160      0.068800
# 1            0.476   0.478  11.0   -11.766   1.0       0.0395      0.779000
# 2            0.683   0.420   5.0    -6.510   1.0       0.0542      0.087500
# 3            0.596   0.522   9.0    -6.633   1.0       0.0358      0.373000
# 4            0.718   0.691   4.0    -6.440   1.0       0.0387      0.015900
# ...            ...     ...   ...       ...   ...          ...           ...
# 1809         0.609   0.435  11.0    -7.861   0.0       0.2850      0.522000
# 1810         0.864   0.689  10.0    -7.273   0.0       0.2200      0.000077
# 1811         0.786   0.808   7.0    -3.702   1.0       0.0881      0.084600
# 1812         0.694   0.669   8.0    -5.143   0.0       0.1150      0.079400
# 1813         0.616   0.474  10.0    -9.608   1.0       0.0266      0.192000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1700    0.817  155.866  audio_features
# 1             0.117000    0.1030    0.489   89.060  audio_features
# 2             0.000000    0.2250    0.469  128.621  audio_features
# 3             0.000000    0.2910    0.443   76.042  audio_features
# 4             0.000000    0.0627    0.552  100.008  audio_features
# ...                ...       ...      ...      ...             ...
# 1809          0.000000    0.1180    0.552  131.995  audio_features
# 1810          0.000467    0.1110    0.412  152.946  audio_features
# 1811          0.000289    0.0822    0.608  105.029  audio_features
# 1812          0.000000    0.2960    0.522  128.083  audio_features
# 1813          0.007620    0.0989    0.493  142.689  audio_features
#
#                           id                                   uri  \
# 0     2twGKYnxAYNRQ9z9F3sQ4o  spotify:track:2twGKYnxAYNRQ9z9F3sQ4o
# 1     6Kn5yzAyOw3jf4Y5a6d1Oq  spotify:track:6Kn5yzAyOw3jf4Y5a6d1Oq
# 2     1YlulsUKDduOmC7WxvXYPW  spotify:track:1YlulsUKDduOmC7WxvXYPW
# 3     3DA4SE262k6rdEtlHteNyq  spotify:track:3DA4SE262k6rdEtlHteNyq
# 4     6ihL9TjfRjadfEePzXXyVF  spotify:track:6ihL9TjfRjadfEePzXXyVF
# ...                      ...                                   ...
# 1809  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 1810  3cFHCXuBZKMJd8Q4Wt8RB3  spotify:track:3cFHCXuBZKMJd8Q4Wt8RB3
# 1811  0KkIkfsLEJbrcIhYsCL7L5  spotify:track:0KkIkfsLEJbrcIhYsCL7L5
# 1812  6NtUvEqIOgO1rRkQk6F0aE  spotify:track:6NtUvEqIOgO1rRkQk6F0aE
# 1813  68JS5SFTnW5Yv9Vzw81Jf0  spotify:track:68JS5SFTnW5Yv9Vzw81Jf0
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2twGKYnxAYNR...
# 1     https://api.spotify.com/v1/tracks/6Kn5yzAyOw3j...
# 2     https://api.spotify.com/v1/tracks/1YlulsUKDduO...
# 3     https://api.spotify.com/v1/tracks/3DA4SE262k6r...
# 4     https://api.spotify.com/v1/tracks/6ihL9TjfRjad...
# ...                                                 ...
# 1809  https://api.spotify.com/v1/tracks/4TTV7EcfroSL...
# 1810  https://api.spotify.com/v1/tracks/3cFHCXuBZKMJ...
# 1811  https://api.spotify.com/v1/tracks/0KkIkfsLEJbr...
# 1812  https://api.spotify.com/v1/tracks/6NtUvEqIOgO1...
# 1813  https://api.spotify.com/v1/tracks/68JS5SFTnW5Y...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2twG...     184673.0
# 1     https://api.spotify.com/v1/audio-analysis/6Kn5...     259080.0
# 2     https://api.spotify.com/v1/audio-analysis/1Ylu...     213507.0
# 3     https://api.spotify.com/v1/audio-analysis/3DA4...     188320.0
# 4     https://api.spotify.com/v1/audio-analysis/6ihL...     213107.0
# ...                                                 ...          ...
# 1809  https://api.spotify.com/v1/audio-analysis/4TTV...     236738.0
# 1810  https://api.spotify.com/v1/audio-analysis/3cFH...     148246.0
# 1811  https://api.spotify.com/v1/audio-analysis/0KkI...     301714.0
# 1812  https://api.spotify.com/v1/audio-analysis/6NtU...     197720.0
# 1813  https://api.spotify.com/v1/audio-analysis/68JS...     210133.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 1809             4.0
# 1810             4.0
# 1811             4.0
# 1812             4.0
# 1813             4.0
#
# [1814 rows x 18 columns]

# %%
audio_df['success'] = 0.0

# %%
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.728   0.656   6.0    -5.652   1.0       0.4160      0.068800
# 1            0.476   0.478  11.0   -11.766   1.0       0.0395      0.779000
# 2            0.683   0.420   5.0    -6.510   1.0       0.0542      0.087500
# 3            0.596   0.522   9.0    -6.633   1.0       0.0358      0.373000
# 4            0.718   0.691   4.0    -6.440   1.0       0.0387      0.015900
# ...            ...     ...   ...       ...   ...          ...           ...
# 1809         0.609   0.435  11.0    -7.861   0.0       0.2850      0.522000
# 1810         0.864   0.689  10.0    -7.273   0.0       0.2200      0.000077
# 1811         0.786   0.808   7.0    -3.702   1.0       0.0881      0.084600
# 1812         0.694   0.669   8.0    -5.143   0.0       0.1150      0.079400
# 1813         0.616   0.474  10.0    -9.608   1.0       0.0266      0.192000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1700    0.817  155.866  audio_features
# 1             0.117000    0.1030    0.489   89.060  audio_features
# 2             0.000000    0.2250    0.469  128.621  audio_features
# 3             0.000000    0.2910    0.443   76.042  audio_features
# 4             0.000000    0.0627    0.552  100.008  audio_features
# ...                ...       ...      ...      ...             ...
# 1809          0.000000    0.1180    0.552  131.995  audio_features
# 1810          0.000467    0.1110    0.412  152.946  audio_features
# 1811          0.000289    0.0822    0.608  105.029  audio_features
# 1812          0.000000    0.2960    0.522  128.083  audio_features
# 1813          0.007620    0.0989    0.493  142.689  audio_features
#
#                           id                                   uri  \
# 0     2twGKYnxAYNRQ9z9F3sQ4o  spotify:track:2twGKYnxAYNRQ9z9F3sQ4o
# 1     6Kn5yzAyOw3jf4Y5a6d1Oq  spotify:track:6Kn5yzAyOw3jf4Y5a6d1Oq
# 2     1YlulsUKDduOmC7WxvXYPW  spotify:track:1YlulsUKDduOmC7WxvXYPW
# 3     3DA4SE262k6rdEtlHteNyq  spotify:track:3DA4SE262k6rdEtlHteNyq
# 4     6ihL9TjfRjadfEePzXXyVF  spotify:track:6ihL9TjfRjadfEePzXXyVF
# ...                      ...                                   ...
# 1809  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 1810  3cFHCXuBZKMJd8Q4Wt8RB3  spotify:track:3cFHCXuBZKMJd8Q4Wt8RB3
# 1811  0KkIkfsLEJbrcIhYsCL7L5  spotify:track:0KkIkfsLEJbrcIhYsCL7L5
# 1812  6NtUvEqIOgO1rRkQk6F0aE  spotify:track:6NtUvEqIOgO1rRkQk6F0aE
# 1813  68JS5SFTnW5Yv9Vzw81Jf0  spotify:track:68JS5SFTnW5Yv9Vzw81Jf0
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2twGKYnxAYNR...
# 1     https://api.spotify.com/v1/tracks/6Kn5yzAyOw3j...
# 2     https://api.spotify.com/v1/tracks/1YlulsUKDduO...
# 3     https://api.spotify.com/v1/tracks/3DA4SE262k6r...
# 4     https://api.spotify.com/v1/tracks/6ihL9TjfRjad...
# ...                                                 ...
# 1809  https://api.spotify.com/v1/tracks/4TTV7EcfroSL...
# 1810  https://api.spotify.com/v1/tracks/3cFHCXuBZKMJ...
# 1811  https://api.spotify.com/v1/tracks/0KkIkfsLEJbr...
# 1812  https://api.spotify.com/v1/tracks/6NtUvEqIOgO1...
# 1813  https://api.spotify.com/v1/tracks/68JS5SFTnW5Y...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2twG...     184673.0
# 1     https://api.spotify.com/v1/audio-analysis/6Kn5...     259080.0
# 2     https://api.spotify.com/v1/audio-analysis/1Ylu...     213507.0
# 3     https://api.spotify.com/v1/audio-analysis/3DA4...     188320.0
# 4     https://api.spotify.com/v1/audio-analysis/6ihL...     213107.0
# ...                                                 ...          ...
# 1809  https://api.spotify.com/v1/audio-analysis/4TTV...     236738.0
# 1810  https://api.spotify.com/v1/audio-analysis/3cFH...     148246.0
# 1811  https://api.spotify.com/v1/audio-analysis/0KkI...     301714.0
# 1812  https://api.spotify.com/v1/audio-analysis/6NtU...     197720.0
# 1813  https://api.spotify.com/v1/audio-analysis/68JS...     210133.0
#
#       time_signature  success
# 0                4.0      1.0
# 1                4.0      1.0
# 2                4.0      1.0
# 3                4.0      1.0
# 4                4.0      1.0
# ...              ...      ...
# 1809             4.0      1.0
# 1810             4.0      1.0
# 1811             4.0      1.0
# 1812             4.0      1.0
# 1813             4.0      1.0
#
# [1814 rows x 19 columns]

# %%
audio_df.to_csv('1814_random_songs_with_audio_features.csv', encoding='utf-8', index=False)

# %%
# Concatenating several csv files

# %%
df = pd.concat(map(pd.read_csv, 
                   ['7808_random_songs_with_audio_features.csv',
                    '1814_random_songs_with_audio_features.csv'], 
                  ), ignore_index=True)

# %%
df['success'] = 0.0
df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.413   0.807  11.0    -3.499   0.0       0.3180      0.053600
# 1            0.131   0.279   0.0   -13.504   1.0       0.0379      0.704000
# 2            0.373   0.249   2.0   -23.432   0.0       0.0477      0.995000
# 3            0.751   0.672   1.0    -3.017   1.0       0.2450      0.006980
# 4            0.831   0.795   1.0    -6.186   1.0       0.2640      0.221000
# ...            ...     ...   ...       ...   ...          ...           ...
# 9617         0.609   0.435  11.0    -7.861   0.0       0.2850      0.522000
# 9618         0.864   0.689  10.0    -7.273   0.0       0.2200      0.000077
# 9619         0.786   0.808   7.0    -3.702   1.0       0.0881      0.084600
# 9620         0.694   0.669   8.0    -5.143   0.0       0.1150      0.079400
# 9621         0.616   0.474  10.0    -9.608   1.0       0.0266      0.192000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6310    0.438  149.330  audio_features
# 1             0.002490    0.1210    0.175  179.252  audio_features
# 2             0.920000    0.1060    0.656  148.346  audio_features
# 3             0.000000    0.1720    0.340  158.087  audio_features
# 4             0.000000    0.2910    0.744  160.063  audio_features
# ...                ...       ...      ...      ...             ...
# 9617          0.000000    0.1180    0.552  131.995  audio_features
# 9618          0.000467    0.1110    0.412  152.946  audio_features
# 9619          0.000289    0.0822    0.608  105.029  audio_features
# 9620          0.000000    0.2960    0.522  128.083  audio_features
# 9621          0.007620    0.0989    0.493  142.689  audio_features
#
#                           id                                   uri  \
# 0     608a1wIsSd5KzMEqm1O7w3  spotify:track:608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M  spotify:track:33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt  spotify:track:5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp  spotify:track:4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ  spotify:track:21kOVEG3bDCVphKhXL8XmQ
# ...                      ...                                   ...
# 9617  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 9618  3cFHCXuBZKMJd8Q4Wt8RB3  spotify:track:3cFHCXuBZKMJd8Q4Wt8RB3
# 9619  0KkIkfsLEJbrcIhYsCL7L5  spotify:track:0KkIkfsLEJbrcIhYsCL7L5
# 9620  6NtUvEqIOgO1rRkQk6F0aE  spotify:track:6NtUvEqIOgO1rRkQk6F0aE
# 9621  68JS5SFTnW5Yv9Vzw81Jf0  spotify:track:68JS5SFTnW5Yv9Vzw81Jf0
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/608a1wIsSd5K...
# 1     https://api.spotify.com/v1/tracks/33VcQq9PLgJh...
# 2     https://api.spotify.com/v1/tracks/5mI9HJdkqtqW...
# 3     https://api.spotify.com/v1/tracks/4FDG9SHyQkxk...
# 4     https://api.spotify.com/v1/tracks/21kOVEG3bDCV...
# ...                                                 ...
# 9617  https://api.spotify.com/v1/tracks/4TTV7EcfroSL...
# 9618  https://api.spotify.com/v1/tracks/3cFHCXuBZKMJ...
# 9619  https://api.spotify.com/v1/tracks/0KkIkfsLEJbr...
# 9620  https://api.spotify.com/v1/tracks/6NtUvEqIOgO1...
# 9621  https://api.spotify.com/v1/tracks/68JS5SFTnW5Y...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/608a...     296147.0
# 1     https://api.spotify.com/v1/audio-analysis/33Vc...     201080.0
# 2     https://api.spotify.com/v1/audio-analysis/5mI9...     132000.0
# 3     https://api.spotify.com/v1/audio-analysis/4FDG...     195818.0
# 4     https://api.spotify.com/v1/audio-analysis/21kO...      96064.0
# ...                                                 ...          ...
# 9617  https://api.spotify.com/v1/audio-analysis/4TTV...     236738.0
# 9618  https://api.spotify.com/v1/audio-analysis/3cFH...     148246.0
# 9619  https://api.spotify.com/v1/audio-analysis/0KkI...     301714.0
# 9620  https://api.spotify.com/v1/audio-analysis/6NtU...     197720.0
# 9621  https://api.spotify.com/v1/audio-analysis/68JS...     210133.0
#
#       time_signature  success
# 0                4.0      0.0
# 1                4.0      0.0
# 2                4.0      0.0
# 3                4.0      0.0
# 4                4.0      0.0
# ...              ...      ...
# 9617             4.0      0.0
# 9618             4.0      0.0
# 9619             4.0      0.0
# 9620             4.0      0.0
# 9621             4.0      0.0
#
# [9622 rows x 19 columns]

# %%
df[df.duplicated(subset=['id'])]
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 7811         0.596   0.522   9.0    -6.633   1.0       0.0358      0.373000
# 7812         0.718   0.691   4.0    -6.440   1.0       0.0387      0.015900
# 7814         0.525   0.774   9.0    -4.532   1.0       0.2410      0.240000
# 7815         0.771   0.700   1.0    -6.460   1.0       0.2330      0.032300
# 7816         0.722   0.758  11.0    -4.477   0.0       0.0471      0.011100
# ...            ...     ...   ...       ...   ...          ...           ...
# 9601         0.388   0.595   1.0    -9.799   1.0       0.0325      0.663000
# 9609         0.606   0.826   0.0    -6.040   1.0       0.0307      0.025600
# 9612         0.653   0.796   7.0    -4.050   0.0       0.2450      0.240000
# 9618         0.864   0.689  10.0    -7.273   0.0       0.2200      0.000077
# 9621         0.616   0.474  10.0    -9.608   1.0       0.0266      0.192000
#
#       instrumentalness  liveness  valence    tempo            type  \
# 7811          0.000000    0.2910    0.443   76.042  audio_features
# 7812          0.000000    0.0627    0.552  100.008  audio_features
# 7814          0.000001    0.4950    0.526  154.192  audio_features
# 7815          0.000000    0.0911    0.417  141.065  audio_features
# 7816          0.000000    0.3080    0.620  128.047  audio_features
# ...                ...       ...      ...      ...             ...
# 9601          0.000056    0.1780    0.596  190.043  audio_features
# 9609          0.000016    0.1170    0.322  121.040  audio_features
# 9612          0.000000    0.1080    0.405  160.026  audio_features
# 9618          0.000467    0.1110    0.412  152.946  audio_features
# 9621          0.007620    0.0989    0.493  142.689  audio_features
#
#                           id                                   uri  \
# 7811  3DA4SE262k6rdEtlHteNyq  spotify:track:3DA4SE262k6rdEtlHteNyq
# 7812  6ihL9TjfRjadfEePzXXyVF  spotify:track:6ihL9TjfRjadfEePzXXyVF
# 7814  5h0Jgt873QtgL6nJRBGfT6  spotify:track:5h0Jgt873QtgL6nJRBGfT6
# 7815  1TcJDKandYbyo4cCHhKzgr  spotify:track:1TcJDKandYbyo4cCHhKzgr
# 7816  7LcfRTgAVTs5pQGEQgUEzN  spotify:track:7LcfRTgAVTs5pQGEQgUEzN
# ...                      ...                                   ...
# 9601  08cXy6KUizaAelYXtcew3w  spotify:track:08cXy6KUizaAelYXtcew3w
# 9609  4rsW3WCZBGwhHfJWuHRwyT  spotify:track:4rsW3WCZBGwhHfJWuHRwyT
# 9612  0aQA9DP54h37OevE7hRc2a  spotify:track:0aQA9DP54h37OevE7hRc2a
# 9618  3cFHCXuBZKMJd8Q4Wt8RB3  spotify:track:3cFHCXuBZKMJd8Q4Wt8RB3
# 9621  68JS5SFTnW5Yv9Vzw81Jf0  spotify:track:68JS5SFTnW5Yv9Vzw81Jf0
#
#                                              track_href  \
# 7811  https://api.spotify.com/v1/tracks/3DA4SE262k6r...
# 7812  https://api.spotify.com/v1/tracks/6ihL9TjfRjad...
# 7814  https://api.spotify.com/v1/tracks/5h0Jgt873Qtg...
# 7815  https://api.spotify.com/v1/tracks/1TcJDKandYby...
# 7816  https://api.spotify.com/v1/tracks/7LcfRTgAVTs5...
# ...                                                 ...
# 9601  https://api.spotify.com/v1/tracks/08cXy6KUizaA...
# 9609  https://api.spotify.com/v1/tracks/4rsW3WCZBGwh...
# 9612  https://api.spotify.com/v1/tracks/0aQA9DP54h37...
# 9618  https://api.spotify.com/v1/tracks/3cFHCXuBZKMJ...
# 9621  https://api.spotify.com/v1/tracks/68JS5SFTnW5Y...
#
#                                            analysis_url  duration_ms  \
# 7811  https://api.spotify.com/v1/audio-analysis/3DA4...     188320.0
# 7812  https://api.spotify.com/v1/audio-analysis/6ihL...     213107.0
# 7814  https://api.spotify.com/v1/audio-analysis/5h0J...     202391.0
# 7815  https://api.spotify.com/v1/audio-analysis/1TcJ...     191771.0
# 7816  https://api.spotify.com/v1/audio-analysis/7Lcf...     201160.0
# ...                                                 ...          ...
# 9601  https://api.spotify.com/v1/audio-analysis/08cX...     204213.0
# 9609  https://api.spotify.com/v1/audio-analysis/4rsW...     210173.0
# 9612  https://api.spotify.com/v1/audio-analysis/0aQA...     252712.0
# 9618  https://api.spotify.com/v1/audio-analysis/3cFH...     148246.0
# 9621  https://api.spotify.com/v1/audio-analysis/68JS...     210133.0
#
#       time_signature  success
# 7811             4.0      0.0
# 7812             4.0      0.0
# 7814             4.0      0.0
# 7815             4.0      0.0
# 7816             4.0      0.0
# ...              ...      ...
# 9601             4.0      0.0
# 9609             4.0      0.0
# 9612             4.0      0.0
# 9618             4.0      0.0
# 9621             4.0      0.0
#
# [823 rows x 19 columns]

# %%
df.drop_duplicates(subset=['id'], inplace=True)
df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.413   0.807  11.0    -3.499   0.0       0.3180      0.053600
# 1            0.131   0.279   0.0   -13.504   1.0       0.0379      0.704000
# 2            0.373   0.249   2.0   -23.432   0.0       0.0477      0.995000
# 3            0.751   0.672   1.0    -3.017   1.0       0.2450      0.006980
# 4            0.831   0.795   1.0    -6.186   1.0       0.2640      0.221000
# ...            ...     ...   ...       ...   ...          ...           ...
# 9615         0.604   0.950   9.0    -6.144   0.0       0.1740      0.000106
# 9616         0.470   0.116   4.0   -24.948   1.0       0.0440      0.994000
# 9617         0.609   0.435  11.0    -7.861   0.0       0.2850      0.522000
# 9619         0.786   0.808   7.0    -3.702   1.0       0.0881      0.084600
# 9620         0.694   0.669   8.0    -5.143   0.0       0.1150      0.079400
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6310    0.438  149.330  audio_features
# 1             0.002490    0.1210    0.175  179.252  audio_features
# 2             0.920000    0.1060    0.656  148.346  audio_features
# 3             0.000000    0.1720    0.340  158.087  audio_features
# 4             0.000000    0.2910    0.744  160.063  audio_features
# ...                ...       ...      ...      ...             ...
# 9615          0.730000    0.3140    0.368  125.978  audio_features
# 9616          0.918000    0.1430    0.877   93.801  audio_features
# 9617          0.000000    0.1180    0.552  131.995  audio_features
# 9619          0.000289    0.0822    0.608  105.029  audio_features
# 9620          0.000000    0.2960    0.522  128.083  audio_features
#
#                           id                                   uri  \
# 0     608a1wIsSd5KzMEqm1O7w3  spotify:track:608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M  spotify:track:33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt  spotify:track:5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp  spotify:track:4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ  spotify:track:21kOVEG3bDCVphKhXL8XmQ
# ...                      ...                                   ...
# 9615  6l0Xa0PJ04RQlyjJt4JDRB  spotify:track:6l0Xa0PJ04RQlyjJt4JDRB
# 9616  1qSyStOitrHUti4xyuqwil  spotify:track:1qSyStOitrHUti4xyuqwil
# 9617  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 9619  0KkIkfsLEJbrcIhYsCL7L5  spotify:track:0KkIkfsLEJbrcIhYsCL7L5
# 9620  6NtUvEqIOgO1rRkQk6F0aE  spotify:track:6NtUvEqIOgO1rRkQk6F0aE
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/608a1wIsSd5K...
# 1     https://api.spotify.com/v1/tracks/33VcQq9PLgJh...
# 2     https://api.spotify.com/v1/tracks/5mI9HJdkqtqW...
# 3     https://api.spotify.com/v1/tracks/4FDG9SHyQkxk...
# 4     https://api.spotify.com/v1/tracks/21kOVEG3bDCV...
# ...                                                 ...
# 9615  https://api.spotify.com/v1/tracks/6l0Xa0PJ04RQ...
# 9616  https://api.spotify.com/v1/tracks/1qSyStOitrHU...
# 9617  https://api.spotify.com/v1/tracks/4TTV7EcfroSL...
# 9619  https://api.spotify.com/v1/tracks/0KkIkfsLEJbr...
# 9620  https://api.spotify.com/v1/tracks/6NtUvEqIOgO1...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/608a...     296147.0
# 1     https://api.spotify.com/v1/audio-analysis/33Vc...     201080.0
# 2     https://api.spotify.com/v1/audio-analysis/5mI9...     132000.0
# 3     https://api.spotify.com/v1/audio-analysis/4FDG...     195818.0
# 4     https://api.spotify.com/v1/audio-analysis/21kO...      96064.0
# ...                                                 ...          ...
# 9615  https://api.spotify.com/v1/audio-analysis/6l0X...     197143.0
# 9616  https://api.spotify.com/v1/audio-analysis/1qSy...      96093.0
# 9617  https://api.spotify.com/v1/audio-analysis/4TTV...     236738.0
# 9619  https://api.spotify.com/v1/audio-analysis/0KkI...     301714.0
# 9620  https://api.spotify.com/v1/audio-analysis/6NtU...     197720.0
#
#       time_signature  success
# 0                4.0      0.0
# 1                4.0      0.0
# 2                4.0      0.0
# 3                4.0      0.0
# 4                4.0      0.0
# ...              ...      ...
# 9615             4.0      0.0
# 9616             1.0      0.0
# 9617             4.0      0.0
# 9619             4.0      0.0
# 9620             4.0      0.0
#
# [8799 rows x 19 columns]

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.413   0.807  11.0    -3.499   0.0       0.3180      0.053600
# 1            0.131   0.279   0.0   -13.504   1.0       0.0379      0.704000
# 2            0.373   0.249   2.0   -23.432   0.0       0.0477      0.995000
# 3            0.751   0.672   1.0    -3.017   1.0       0.2450      0.006980
# 4            0.831   0.795   1.0    -6.186   1.0       0.2640      0.221000
# ...            ...     ...   ...       ...   ...          ...           ...
# 8794         0.604   0.950   9.0    -6.144   0.0       0.1740      0.000106
# 8795         0.470   0.116   4.0   -24.948   1.0       0.0440      0.994000
# 8796         0.609   0.435  11.0    -7.861   0.0       0.2850      0.522000
# 8797         0.786   0.808   7.0    -3.702   1.0       0.0881      0.084600
# 8798         0.694   0.669   8.0    -5.143   0.0       0.1150      0.079400
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.6310    0.438  149.330  audio_features
# 1             0.002490    0.1210    0.175  179.252  audio_features
# 2             0.920000    0.1060    0.656  148.346  audio_features
# 3             0.000000    0.1720    0.340  158.087  audio_features
# 4             0.000000    0.2910    0.744  160.063  audio_features
# ...                ...       ...      ...      ...             ...
# 8794          0.730000    0.3140    0.368  125.978  audio_features
# 8795          0.918000    0.1430    0.877   93.801  audio_features
# 8796          0.000000    0.1180    0.552  131.995  audio_features
# 8797          0.000289    0.0822    0.608  105.029  audio_features
# 8798          0.000000    0.2960    0.522  128.083  audio_features
#
#                           id                                   uri  \
# 0     608a1wIsSd5KzMEqm1O7w3  spotify:track:608a1wIsSd5KzMEqm1O7w3
# 1     33VcQq9PLgJhMllZtPRP4M  spotify:track:33VcQq9PLgJhMllZtPRP4M
# 2     5mI9HJdkqtqWr7KsA8hIbt  spotify:track:5mI9HJdkqtqWr7KsA8hIbt
# 3     4FDG9SHyQkxkJxGLrF1ZIp  spotify:track:4FDG9SHyQkxkJxGLrF1ZIp
# 4     21kOVEG3bDCVphKhXL8XmQ  spotify:track:21kOVEG3bDCVphKhXL8XmQ
# ...                      ...                                   ...
# 8794  6l0Xa0PJ04RQlyjJt4JDRB  spotify:track:6l0Xa0PJ04RQlyjJt4JDRB
# 8795  1qSyStOitrHUti4xyuqwil  spotify:track:1qSyStOitrHUti4xyuqwil
# 8796  4TTV7EcfroSLWzXRY6gLv6  spotify:track:4TTV7EcfroSLWzXRY6gLv6
# 8797  0KkIkfsLEJbrcIhYsCL7L5  spotify:track:0KkIkfsLEJbrcIhYsCL7L5
# 8798  6NtUvEqIOgO1rRkQk6F0aE  spotify:track:6NtUvEqIOgO1rRkQk6F0aE
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/608a1wIsSd5K...
# 1     https://api.spotify.com/v1/tracks/33VcQq9PLgJh...
# 2     https://api.spotify.com/v1/tracks/5mI9HJdkqtqW...
# 3     https://api.spotify.com/v1/tracks/4FDG9SHyQkxk...
# 4     https://api.spotify.com/v1/tracks/21kOVEG3bDCV...
# ...                                                 ...
# 8794  https://api.spotify.com/v1/tracks/6l0Xa0PJ04RQ...
# 8795  https://api.spotify.com/v1/tracks/1qSyStOitrHU...
# 8796  https://api.spotify.com/v1/tracks/4TTV7EcfroSL...
# 8797  https://api.spotify.com/v1/tracks/0KkIkfsLEJbr...
# 8798  https://api.spotify.com/v1/tracks/6NtUvEqIOgO1...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/608a...     296147.0
# 1     https://api.spotify.com/v1/audio-analysis/33Vc...     201080.0
# 2     https://api.spotify.com/v1/audio-analysis/5mI9...     132000.0
# 3     https://api.spotify.com/v1/audio-analysis/4FDG...     195818.0
# 4     https://api.spotify.com/v1/audio-analysis/21kO...      96064.0
# ...                                                 ...          ...
# 8794  https://api.spotify.com/v1/audio-analysis/6l0X...     197143.0
# 8795  https://api.spotify.com/v1/audio-analysis/1qSy...      96093.0
# 8796  https://api.spotify.com/v1/audio-analysis/4TTV...     236738.0
# 8797  https://api.spotify.com/v1/audio-analysis/0KkI...     301714.0
# 8798  https://api.spotify.com/v1/audio-analysis/6NtU...     197720.0
#
#       time_signature  success
# 0                4.0      0.0
# 1                4.0      0.0
# 2                4.0      0.0
# 3                4.0      0.0
# 4                4.0      0.0
# ...              ...      ...
# 8794             4.0      0.0
# 8795             1.0      0.0
# 8796             4.0      0.0
# 8797             4.0      0.0
# 8798             4.0      0.0
#
# [8799 rows x 19 columns]

# %%
df.to_csv('8799_random_songs_with_audio_features.csv', encoding='utf-8', index=False)
