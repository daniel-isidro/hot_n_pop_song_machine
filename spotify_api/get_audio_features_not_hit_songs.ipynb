# %%
import numpy as np
import pandas as pd
import json
import os
import random
import string
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

pd.set_option("max_rows", 10)

# %%
# Reading Spotify web API credentials from settings.env hidden file

with open('settings.env') as f:
    env_vars = json.loads(f.read())

# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = env_vars['SPOTIPY_CLIENT_ID']
os.environ['SPOTIPY_CLIENT_SECRET'] = env_vars['SPOTIPY_CLIENT_SECRET']

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
# Getting 10,000 pseudo-random songs to balance the hit/not-hit songs datasets
# Year range same as selected for hit songs: 2000-2020

track_id_list = []

for i in range(0,10000):
    
    wildcard = [random.choice(string.ascii_letters + string.digits) + '%25',
                '%25' + random.choice(string.ascii_letters + string.digits),
                '%25' + random.choice(string.ascii_letters + string.digits) + '%25']
    
    random_char = random.choice(wildcard)
    
    search = sp.search(q=random_char + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    
    track_id = search['tracks']['items'][0]['id']
    if track_id is None:
        track_id_list.append(np.nan)
    else:
        track_id_list.append(track_id)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-36-d6e6f2cf95d1> in <module>
#      17                    offset=random.randint(0,1990))
#      18
# ---> 19     track_id = search['tracks']['items'][0]['id']
#      20     if track_id is None:
#      21         track_id_list.append(np.nan)
#
# IndexError: list index out of range

# %%
len(track_id_list)
# Out:
# 3234

# %%
# Spotify capped at 3234 songs
# Rinse and repeat, adding more tracks to track_id_list

#track_id_list = []

for i in range(0,10000):
    
    wildcard = [random.choice(string.ascii_letters + string.digits) + '%25',
                '%25' + random.choice(string.ascii_letters + string.digits),
                '%25' + random.choice(string.ascii_letters + string.digits) + '%25']
    
    random_char = random.choice(wildcard)
    
    search = sp.search(q=random_char + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    
    track_id = search['tracks']['items'][0]['id']
    if track_id is None:
        track_id_list.append(np.nan)
    else:
        track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 13234

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
df
# Out:
#                      track_id
# 0      2h3OD7psc46VriLAocmNXX
# 1      6n2q9hCLbIwKesMi4aFXZn
# 2      2QunlTaeHvNx773hR5mKjR
# 3      5pPeWvlH7T74gLBmUKtUde
# 4      70D5WTh5yGvDeRinBNE1Nw
# ...                       ...
# 13229  1wVyjIbWNzd9M8uTC9hKKz
# 13230  1ZDn83aJISoW0qXomuTg9c
# 13231  7uHXdPPYhu5TCwWsdtHJuk
# 13232  1V0zsWLBuuEgb5kbkIjO83
# 13233  2iHUZVVLdus1Etekvqrb96
#
# [13234 rows x 1 columns]

# %%
# No NaN's

df[df['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 3759 duplicates

df[df.duplicated()].shape
# Out:
# (3759, 1)

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                      track_id
# 0      2h3OD7psc46VriLAocmNXX
# 1      6n2q9hCLbIwKesMi4aFXZn
# 2      2QunlTaeHvNx773hR5mKjR
# 3      5pPeWvlH7T74gLBmUKtUde
# 4      70D5WTh5yGvDeRinBNE1Nw
# ...                       ...
# 13226  331BqvDc63kvhtNuvvEgHj
# 13230  1ZDn83aJISoW0qXomuTg9c
# 13231  7uHXdPPYhu5TCwWsdtHJuk
# 13232  1V0zsWLBuuEgb5kbkIjO83
# 13233  2iHUZVVLdus1Etekvqrb96
#
# [9475 rows x 1 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                     track_id
# 0     2h3OD7psc46VriLAocmNXX
# 1     6n2q9hCLbIwKesMi4aFXZn
# 2     2QunlTaeHvNx773hR5mKjR
# 3     5pPeWvlH7T74gLBmUKtUde
# 4     70D5WTh5yGvDeRinBNE1Nw
# ...                      ...
# 9470  331BqvDc63kvhtNuvvEgHj
# 9471  1ZDn83aJISoW0qXomuTg9c
# 9472  7uHXdPPYhu5TCwWsdtHJuk
# 9473  1V0zsWLBuuEgb5kbkIjO83
# 9474  2iHUZVVLdus1Etekvqrb96
#
# [9475 rows x 1 columns]

# %%
df.to_csv('9475_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
# Get audio_features

audio = [sp.audio_features(x) for x in df['track_id']]

# %%
audio_df = pd.DataFrame()

empty_row = {'danceability': np.nan,
 'energy': np.nan,
 'key': np.nan,
 'loudness': np.nan,
 'mode': np.nan,
 'speechiness': np.nan,
 'acousticness': np.nan,
 'instrumentalness': np.nan,
 'liveness': np.nan,
 'valence': np.nan,
 'tempo': np.nan,
 'type': np.nan,
 'id': np.nan,
 'uri': np.nan,
 'track_href': np.nan,
 'analysis_url': np.nan,
 'duration_ms': np.nan,
 'time_signature': np.nan}

for i in range(0,len(df['track_id'])):
    if type(audio[i][0]) != type(None):
        audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
    else:
        audio_df = audio_df.append(pd.json_normalize(empty_row))

# %%
audio_df.isnull().sum()
# Out:
# danceability      51
# energy            51
# key               51
# loudness          51
# mode              51
#                   ..
# uri               51
# track_href        51
# analysis_url      51
# duration_ms       51
# time_signature    51
# Length: 18, dtype: int64

# %%
audio_df.shape
# Out:
# (9475, 18)

# %%
audio_df[audio_df['danceability'].isnull()]
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# ..           ...     ...  ...       ...   ...          ...           ...
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
# 0            NaN     NaN  NaN       NaN   NaN          NaN           NaN
#
#     instrumentalness  liveness  valence  tempo type   id  uri track_href  \
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# ..               ...       ...      ...    ...  ...  ...  ...        ...
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
# 0                NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
#
#    analysis_url  duration_ms  time_signature
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# ..          ...          ...             ...
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
# 0           NaN          NaN             NaN
#
# [51 rows x 18 columns]

# %%
audio_df.dropna(inplace=True)

# %%
audio_df.reset_index(drop=True, inplace=True)
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.557  0.6550   1.0   -11.170   1.0       0.6350      0.571000
# 1            0.550  0.3630   9.0   -12.857   1.0       0.0520      0.456000
# 2            0.519  0.3030   4.0    -9.981   1.0       0.0417      0.911000
# 3            0.636  0.8440   1.0    -7.007   1.0       0.0443      0.000018
# 4            0.708  0.2870   8.0   -24.331   1.0       0.9050      0.152000
# ...            ...     ...   ...       ...   ...          ...           ...
# 9419         0.718  0.1390  11.0   -20.712   0.0       0.9490      0.947000
# 9420         0.631  0.2360   4.0   -22.540   1.0       0.9390      0.676000
# 9421         0.384  0.0821   6.0   -27.902   1.0       0.0499      0.995000
# 9422         0.769  0.8600   7.0    -4.854   1.0       0.0349      0.000363
# 9423         0.749  0.8000   2.0    -6.412   1.0       0.0367      0.004690
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.8630    0.587   46.801  audio_features
# 1             0.000020    0.2970    0.565  142.977  audio_features
# 2             0.002560    0.0696    0.210  140.406  audio_features
# 3             0.414000    0.2470    0.334  100.030  audio_features
# 4             0.000039    0.2570    0.392  126.382  audio_features
# ...                ...       ...      ...      ...             ...
# 9419          0.000000    0.2040    0.598  120.855  audio_features
# 9420          0.000000    0.2210    0.636  169.984  audio_features
# 9421          0.920000    0.1070    0.612  149.326  audio_features
# 9422          0.000004    0.0385    0.971  120.428  audio_features
# 9423          0.247000    0.2070    0.406  117.003  audio_features
#
#                           id                                   uri  \
# 0     2h3OD7psc46VriLAocmNXX  spotify:track:2h3OD7psc46VriLAocmNXX
# 1     6n2q9hCLbIwKesMi4aFXZn  spotify:track:6n2q9hCLbIwKesMi4aFXZn
# 2     2QunlTaeHvNx773hR5mKjR  spotify:track:2QunlTaeHvNx773hR5mKjR
# 3     5pPeWvlH7T74gLBmUKtUde  spotify:track:5pPeWvlH7T74gLBmUKtUde
# 4     70D5WTh5yGvDeRinBNE1Nw  spotify:track:70D5WTh5yGvDeRinBNE1Nw
# ...                      ...                                   ...
# 9419  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
# 9420  1ZDn83aJISoW0qXomuTg9c  spotify:track:1ZDn83aJISoW0qXomuTg9c
# 9421  7uHXdPPYhu5TCwWsdtHJuk  spotify:track:7uHXdPPYhu5TCwWsdtHJuk
# 9422  1V0zsWLBuuEgb5kbkIjO83  spotify:track:1V0zsWLBuuEgb5kbkIjO83
# 9423  2iHUZVVLdus1Etekvqrb96  spotify:track:2iHUZVVLdus1Etekvqrb96
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2h3OD7psc46V...
# 1     https://api.spotify.com/v1/tracks/6n2q9hCLbIwK...
# 2     https://api.spotify.com/v1/tracks/2QunlTaeHvNx...
# 3     https://api.spotify.com/v1/tracks/5pPeWvlH7T74...
# 4     https://api.spotify.com/v1/tracks/70D5WTh5yGvD...
# ...                                                 ...
# 9419  https://api.spotify.com/v1/tracks/331BqvDc63kv...
# 9420  https://api.spotify.com/v1/tracks/1ZDn83aJISoW...
# 9421  https://api.spotify.com/v1/tracks/7uHXdPPYhu5T...
# 9422  https://api.spotify.com/v1/tracks/1V0zsWLBuuEg...
# 9423  https://api.spotify.com/v1/tracks/2iHUZVVLdus1...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2h3O...     102373.0
# 1     https://api.spotify.com/v1/audio-analysis/6n2q...     457227.0
# 2     https://api.spotify.com/v1/audio-analysis/2Qun...     418368.0
# 3     https://api.spotify.com/v1/audio-analysis/5pPe...     169941.0
# 4     https://api.spotify.com/v1/audio-analysis/70D5...     212964.0
# ...                                                 ...          ...
# 9419  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
# 9420  https://api.spotify.com/v1/audio-analysis/1ZDn...     122100.0
# 9421  https://api.spotify.com/v1/audio-analysis/7uHX...      92507.0
# 9422  https://api.spotify.com/v1/audio-analysis/1V0z...     241773.0
# 9423  https://api.spotify.com/v1/audio-analysis/2iHU...     192817.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                3.0
# ...              ...
# 9419             4.0
# 9420             4.0
# 9421             4.0
# 9422             4.0
# 9423             4.0
#
# [9424 rows x 18 columns]

# %%
audio_df['success'] = 0.0

# %%
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.557  0.6550   1.0   -11.170   1.0       0.6350      0.571000
# 1            0.550  0.3630   9.0   -12.857   1.0       0.0520      0.456000
# 2            0.519  0.3030   4.0    -9.981   1.0       0.0417      0.911000
# 3            0.636  0.8440   1.0    -7.007   1.0       0.0443      0.000018
# 4            0.708  0.2870   8.0   -24.331   1.0       0.9050      0.152000
# ...            ...     ...   ...       ...   ...          ...           ...
# 9419         0.718  0.1390  11.0   -20.712   0.0       0.9490      0.947000
# 9420         0.631  0.2360   4.0   -22.540   1.0       0.9390      0.676000
# 9421         0.384  0.0821   6.0   -27.902   1.0       0.0499      0.995000
# 9422         0.769  0.8600   7.0    -4.854   1.0       0.0349      0.000363
# 9423         0.749  0.8000   2.0    -6.412   1.0       0.0367      0.004690
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.8630    0.587   46.801  audio_features
# 1             0.000020    0.2970    0.565  142.977  audio_features
# 2             0.002560    0.0696    0.210  140.406  audio_features
# 3             0.414000    0.2470    0.334  100.030  audio_features
# 4             0.000039    0.2570    0.392  126.382  audio_features
# ...                ...       ...      ...      ...             ...
# 9419          0.000000    0.2040    0.598  120.855  audio_features
# 9420          0.000000    0.2210    0.636  169.984  audio_features
# 9421          0.920000    0.1070    0.612  149.326  audio_features
# 9422          0.000004    0.0385    0.971  120.428  audio_features
# 9423          0.247000    0.2070    0.406  117.003  audio_features
#
#                           id                                   uri  \
# 0     2h3OD7psc46VriLAocmNXX  spotify:track:2h3OD7psc46VriLAocmNXX
# 1     6n2q9hCLbIwKesMi4aFXZn  spotify:track:6n2q9hCLbIwKesMi4aFXZn
# 2     2QunlTaeHvNx773hR5mKjR  spotify:track:2QunlTaeHvNx773hR5mKjR
# 3     5pPeWvlH7T74gLBmUKtUde  spotify:track:5pPeWvlH7T74gLBmUKtUde
# 4     70D5WTh5yGvDeRinBNE1Nw  spotify:track:70D5WTh5yGvDeRinBNE1Nw
# ...                      ...                                   ...
# 9419  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
# 9420  1ZDn83aJISoW0qXomuTg9c  spotify:track:1ZDn83aJISoW0qXomuTg9c
# 9421  7uHXdPPYhu5TCwWsdtHJuk  spotify:track:7uHXdPPYhu5TCwWsdtHJuk
# 9422  1V0zsWLBuuEgb5kbkIjO83  spotify:track:1V0zsWLBuuEgb5kbkIjO83
# 9423  2iHUZVVLdus1Etekvqrb96  spotify:track:2iHUZVVLdus1Etekvqrb96
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2h3OD7psc46V...
# 1     https://api.spotify.com/v1/tracks/6n2q9hCLbIwK...
# 2     https://api.spotify.com/v1/tracks/2QunlTaeHvNx...
# 3     https://api.spotify.com/v1/tracks/5pPeWvlH7T74...
# 4     https://api.spotify.com/v1/tracks/70D5WTh5yGvD...
# ...                                                 ...
# 9419  https://api.spotify.com/v1/tracks/331BqvDc63kv...
# 9420  https://api.spotify.com/v1/tracks/1ZDn83aJISoW...
# 9421  https://api.spotify.com/v1/tracks/7uHXdPPYhu5T...
# 9422  https://api.spotify.com/v1/tracks/1V0zsWLBuuEg...
# 9423  https://api.spotify.com/v1/tracks/2iHUZVVLdus1...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/2h3O...     102373.0
# 1     https://api.spotify.com/v1/audio-analysis/6n2q...     457227.0
# 2     https://api.spotify.com/v1/audio-analysis/2Qun...     418368.0
# 3     https://api.spotify.com/v1/audio-analysis/5pPe...     169941.0
# 4     https://api.spotify.com/v1/audio-analysis/70D5...     212964.0
# ...                                                 ...          ...
# 9419  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
# 9420  https://api.spotify.com/v1/audio-analysis/1ZDn...     122100.0
# 9421  https://api.spotify.com/v1/audio-analysis/7uHX...      92507.0
# 9422  https://api.spotify.com/v1/audio-analysis/1V0z...     241773.0
# 9423  https://api.spotify.com/v1/audio-analysis/2iHU...     192817.0
#
#       time_signature  success
# 0                4.0      0.0
# 1                4.0      0.0
# 2                4.0      0.0
# 3                4.0      0.0
# 4                3.0      0.0
# ...              ...      ...
# 9419             4.0      0.0
# 9420             4.0      0.0
# 9421             4.0      0.0
# 9422             4.0      0.0
# 9423             4.0      0.0
#
# [9424 rows x 19 columns]

# %%
audio_df.to_csv('9424_random_songs_with_audio_features.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Getting more random not-hit songs to improve the model

# %%
# Getting 10,000 pseudo-random songs to balance the hit/not-hit songs datasets
# Year range same as selected for hit songs: 2000-2020

#track_id_list = []

for i in range(0,10000):
    
    wildcard = [random.choice(string.ascii_letters + string.digits) + '%25',
                '%25' + random.choice(string.ascii_letters + string.digits),
                '%25' + random.choice(string.ascii_letters + string.digits) + '%25']
    
    random_char = random.choice(wildcard)
    
    search = sp.search(q=random_char + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    
    track_id = search['tracks']['items'][0]['id']
    if track_id is None:
        track_id_list.append(np.nan)
    else:
        track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 24290

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
df
# Out:
#                      track_id
# 0      3jLui4jomVtV5IIxVdlXc6
# 1      7A6QJHLybuMSrb6yoXempj
# 2      4b12WupG6EZjCXUxDSUDg0
# 3      2HLhjO1RuzdAnbKN1NXasT
# 4      1K6u8GsGhj1i1YLdw5xW9k
# ...                       ...
# 24285  4G3TChSwzrsMNUBr8nniNl
# 24286  0hFoS6KHyNsw7ed6N34OHJ
# 24287  7ciGjTLjdKNGO6ypIhdirf
# 24288  6WmfR63P8pITWNOXvZCmE9
# 24289  71VOrOPSfWaJg9vZis5h09
#
# [24290 rows x 1 columns]

# %%
# No NaN's

df[df['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 9985 duplicates

df[df.duplicated()].shape
# Out:
# (9985, 1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                      track_id
# 0      3jLui4jomVtV5IIxVdlXc6
# 1      7A6QJHLybuMSrb6yoXempj
# 2      4b12WupG6EZjCXUxDSUDg0
# 3      2HLhjO1RuzdAnbKN1NXasT
# 4      1K6u8GsGhj1i1YLdw5xW9k
# ...                       ...
# 14300  3kFljKgbLoEhcK4ywvHoIq
# 14301  60avJID2555xrhT5db85Kq
# 14302  0mI4jis8ruYzQHHmxFmKyi
# 14303  7ciGjTLjdKNGO6ypIhdirf
# 14304  71VOrOPSfWaJg9vZis5h09
#
# [14305 rows x 1 columns]

# %%
df.to_csv('14305_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
df2 = pd.read_csv('9475_random_songs_2000-2020.csv')

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
df3
# Out:
#                      track_id
# 0      3jLui4jomVtV5IIxVdlXc6
# 1      7A6QJHLybuMSrb6yoXempj
# 2      4b12WupG6EZjCXUxDSUDg0
# 3      2HLhjO1RuzdAnbKN1NXasT
# 4      1K6u8GsGhj1i1YLdw5xW9k
# ...                       ...
# 23775  331BqvDc63kvhtNuvvEgHj
# 23776  1ZDn83aJISoW0qXomuTg9c
# 23777  7uHXdPPYhu5TCwWsdtHJuk
# 23778  1V0zsWLBuuEgb5kbkIjO83
# 23779  2iHUZVVLdus1Etekvqrb96
#
# [23780 rows x 1 columns]

# %%
df3[df3.duplicated()].shape
# Out:
# (4748, 1)

# %%
df3.drop_duplicates(inplace=True)
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#                      track_id
# 0      3jLui4jomVtV5IIxVdlXc6
# 1      7A6QJHLybuMSrb6yoXempj
# 2      4b12WupG6EZjCXUxDSUDg0
# 3      2HLhjO1RuzdAnbKN1NXasT
# 4      1K6u8GsGhj1i1YLdw5xW9k
# ...                       ...
# 19027  1tzc7FS2RoO8ywUIDtVTT8
# 19028  5jeZEby2UbZ68tIJrdOn5c
# 19029  461cvQ7z4CJ2RmLjGQyfu0
# 19030  331BqvDc63kvhtNuvvEgHj
# 19031  1ZDn83aJISoW0qXomuTg9c
#
# [19032 rows x 1 columns]

# %%
df3.to_csv('19032_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
#track_id_list = []

for i in range(0,10000):
    
    wildcard = [random.choice(string.ascii_letters + string.digits) + '%25',
                '%25' + random.choice(string.ascii_letters + string.digits),
                '%25' + random.choice(string.ascii_letters + string.digits) + '%25']
    
    random_char = random.choice(wildcard)
    
    search = sp.search(q=random_char + ' year:2000-2020',
                   type='track',
                   market='US', 
                   offset=random.randint(0,1990))
    
    track_id = search['tracks']['items'][0]['id']
    if track_id is None:
        track_id_list.append(np.nan)
    else:
        track_id_list.append(track_id)

# %%
len(track_id_list)
# Out:
# 30000

# %%
df = pd.DataFrame()
df['track_id'] = track_id_list

# %%
# No NaN's

df[df['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 13729 duplicates

df[df.duplicated()].shape
# Out:
# (13729, 1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#                      track_id
# 0      6E4XJoq6iDeNertmZtANcM
# 1      07zvM3ZiP5Y8GdRWbZ7oNm
# 2      0x5QddVlDUkVkSa1X9R0F6
# 3      2cbLkWOlNWvkkv4FnIKEbq
# 4      1G3xPkCv4SLhZahEomh7QN
# ...                       ...
# 16266  5P3Nq8KSSKm1syKcTBOFBQ
# 16267  4QN1AOzh4T9M8xR13gngwd
# 16268  1opxSjMOP3P8nvNVoxYREI
# 16269  2NBl1sddbb0q5kIg0RQtD7
# 16270  7j8BGkTKqDTMSbE7PTkr1e
#
# [16271 rows x 1 columns]

# %%
df2 = pd.read_csv('19032_random_songs_2000-2020.csv')

# %%
df2.shape
# Out:
# (19032, 1)

# %%
df3 = pd.concat([df, df2], ignore_index=True)

# %%
# No NaN's

df3[df3['track_id'].isnull()]
# Out:
# Empty DataFrame
# Columns: [track_id]
# Index: []

# %%
# 9615 duplicates

df3[df3.duplicated()].shape
# Out:
# (9615, 1)

# %%
df3.drop_duplicates(inplace=True)
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#                      track_id
# 0      6E4XJoq6iDeNertmZtANcM
# 1      07zvM3ZiP5Y8GdRWbZ7oNm
# 2      0x5QddVlDUkVkSa1X9R0F6
# 3      2cbLkWOlNWvkkv4FnIKEbq
# 4      1G3xPkCv4SLhZahEomh7QN
# ...                       ...
# 25683  7CZbuznOPDhScMmCBk7uBO
# 25684  5EJKvxoUymEW3wmbJ1GoEF
# 25685  1tzc7FS2RoO8ywUIDtVTT8
# 25686  5jeZEby2UbZ68tIJrdOn5c
# 25687  331BqvDc63kvhtNuvvEgHj
#
# [25688 rows x 1 columns]

# %%
df3.to_csv('25688_random_songs_2000-2020.csv', encoding='utf-8', index=False)

# %%
df = df3

# %%
df
# Out:
#                      track_id
# 0      6E4XJoq6iDeNertmZtANcM
# 1      07zvM3ZiP5Y8GdRWbZ7oNm
# 2      0x5QddVlDUkVkSa1X9R0F6
# 3      2cbLkWOlNWvkkv4FnIKEbq
# 4      1G3xPkCv4SLhZahEomh7QN
# ...                       ...
# 25683  7CZbuznOPDhScMmCBk7uBO
# 25684  5EJKvxoUymEW3wmbJ1GoEF
# 25685  1tzc7FS2RoO8ywUIDtVTT8
# 25686  5jeZEby2UbZ68tIJrdOn5c
# 25687  331BqvDc63kvhtNuvvEgHj
#
# [25688 rows x 1 columns]

# %%
# Get audio_features in batches to avoid Stopify API disconnections

audio1 = [sp.audio_features(x) for x in df.iloc[0:5000]['track_id']]

# %%
audio2 = [sp.audio_features(x) for x in df.iloc[5001:10000]['track_id']]

# %%
audio3 = [sp.audio_features(x) for x in df.iloc[10001:15000]['track_id']]

# %%
audio4 = [sp.audio_features(x) for x in df.iloc[15001:20000]['track_id']]

# %%
audio5 = [sp.audio_features(x) for x in df.iloc[20001:25000]['track_id']]

# %%
audio6 = [sp.audio_features(x) for x in df.iloc[25001:]['track_id']]

# %%
audio = audio1 + audio2 + audio3 + audio4 + audio5 + audio6

# %%
len(audio)
# Out:
# 25683

# %%
# Converting 'audio' lists into dataframe, including NaN handling

audio_df = pd.DataFrame()

empty_row = {'danceability': np.nan,
 'energy': np.nan,
 'key': np.nan,
 'loudness': np.nan,
 'mode': np.nan,
 'speechiness': np.nan,
 'acousticness': np.nan,
 'instrumentalness': np.nan,
 'liveness': np.nan,
 'valence': np.nan,
 'tempo': np.nan,
 'type': np.nan,
 'id': np.nan,
 'uri': np.nan,
 'track_href': np.nan,
 'analysis_url': np.nan,
 'duration_ms': np.nan,
 'time_signature': np.nan}

for i in range(0,len(df['track_id'])):
    if type(audio[i][0]) != type(None):
        audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
    else:
        audio_df = audio_df.append(pd.json_normalize(empty_row))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-e43cdc01e38d> in <module>
#      21
#      22 for i in range(0,len(df['track_id'])):
# ---> 23     if type(audio[i][0]) != type(None):
#      24         audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
#      25     else:
#
# IndexError: list index out of range

# %%
audio_df.shape
# Out:
# (25683, 18)

# %%
audio_df.isnull().sum()
# Out:
# danceability      1
# energy            1
# key               1
# loudness          1
# mode              1
#                  ..
# uri               1
# track_href        1
# analysis_url      1
# duration_ms       1
# time_signature    1
# Length: 18, dtype: int64

# %%
audio_df[audio_df['danceability'].isnull()]
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           NaN     NaN  NaN       NaN   NaN          NaN           NaN
#
#    instrumentalness  liveness  valence  tempo type   id  uri track_href  \
# 0               NaN       NaN      NaN    NaN  NaN  NaN  NaN        NaN
#
#   analysis_url  duration_ms  time_signature
# 0          NaN          NaN             NaN

# %%
audio_df.dropna(inplace=True)
audio_df.reset_index(drop=True, inplace=True)

# %%
audio_df.shape
# Out:
# (25682, 18)

# %%
audio_df['success'] = 0.0

# %%
audio_df
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.5650  0.1450   6.0   -19.132   1.0       0.7200        0.8840
# 1            0.1760  0.0624   9.0   -26.590   0.0       0.0523        0.9880
# 2            0.7180  0.5060  11.0   -12.246   1.0       0.9410        0.7320
# 3            0.7490  0.6930   6.0    -9.252   0.0       0.2910        0.2820
# 4            0.4160  0.8710   0.0    -6.306   1.0       0.0793        0.0317
# ...             ...     ...   ...       ...   ...          ...           ...
# 25677        0.2080  0.0436   8.0   -24.426   1.0       0.0345        0.9640
# 25678        0.0871  0.4030   1.0   -27.037   1.0       0.2680        0.9340
# 25679        0.2810  0.1780   0.0   -28.276   0.0       0.0856        0.5180
# 25680        0.3830  0.1230   4.0   -18.018   0.0       0.0451        0.9700
# 25681        0.7180  0.1390  11.0   -20.712   0.0       0.9490        0.9470
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.000000    0.9350   0.5040   75.901  audio_features
# 1              0.971000    0.6620   0.1890  171.450  audio_features
# 2              0.000000    0.1860   0.5380   99.652  audio_features
# 3              0.793000    0.1990   0.5530  174.143  audio_features
# 4              0.000024    0.9760   0.6670  102.308  audio_features
# ...                 ...       ...      ...      ...             ...
# 25677          0.876000    0.0807   0.0372   81.713  audio_features
# 25678          0.624000    0.1330   0.2470   83.861  audio_features
# 25679          0.000128    0.2640   0.4240  130.658  audio_features
# 25680          0.000000    0.2120   0.6820   77.449  audio_features
# 25681          0.000000    0.2040   0.5980  120.855  audio_features
#
#                            id                                   uri  \
# 0      6E4XJoq6iDeNertmZtANcM  spotify:track:6E4XJoq6iDeNertmZtANcM
# 1      07zvM3ZiP5Y8GdRWbZ7oNm  spotify:track:07zvM3ZiP5Y8GdRWbZ7oNm
# 2      0x5QddVlDUkVkSa1X9R0F6  spotify:track:0x5QddVlDUkVkSa1X9R0F6
# 3      2cbLkWOlNWvkkv4FnIKEbq  spotify:track:2cbLkWOlNWvkkv4FnIKEbq
# 4      1G3xPkCv4SLhZahEomh7QN  spotify:track:1G3xPkCv4SLhZahEomh7QN
# ...                       ...                                   ...
# 25677  7CZbuznOPDhScMmCBk7uBO  spotify:track:7CZbuznOPDhScMmCBk7uBO
# 25678  5EJKvxoUymEW3wmbJ1GoEF  spotify:track:5EJKvxoUymEW3wmbJ1GoEF
# 25679  1tzc7FS2RoO8ywUIDtVTT8  spotify:track:1tzc7FS2RoO8ywUIDtVTT8
# 25680  5jeZEby2UbZ68tIJrdOn5c  spotify:track:5jeZEby2UbZ68tIJrdOn5c
# 25681  331BqvDc63kvhtNuvvEgHj  spotify:track:331BqvDc63kvhtNuvvEgHj
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/6E4XJoq6iDeN...
# 1      https://api.spotify.com/v1/tracks/07zvM3ZiP5Y8...
# 2      https://api.spotify.com/v1/tracks/0x5QddVlDUkV...
# 3      https://api.spotify.com/v1/tracks/2cbLkWOlNWvk...
# 4      https://api.spotify.com/v1/tracks/1G3xPkCv4SLh...
# ...                                                  ...
# 25677  https://api.spotify.com/v1/tracks/7CZbuznOPDhS...
# 25678  https://api.spotify.com/v1/tracks/5EJKvxoUymEW...
# 25679  https://api.spotify.com/v1/tracks/1tzc7FS2RoO8...
# 25680  https://api.spotify.com/v1/tracks/5jeZEby2UbZ6...
# 25681  https://api.spotify.com/v1/tracks/331BqvDc63kv...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/6E4X...     287360.0
# 1      https://api.spotify.com/v1/audio-analysis/07zv...     120226.0
# 2      https://api.spotify.com/v1/audio-analysis/0x5Q...     131114.0
# 3      https://api.spotify.com/v1/audio-analysis/2cbL...     302453.0
# 4      https://api.spotify.com/v1/audio-analysis/1G3x...     469294.0
# ...                                                  ...          ...
# 25677  https://api.spotify.com/v1/audio-analysis/7CZb...     179693.0
# 25678  https://api.spotify.com/v1/audio-analysis/5EJK...     214901.0
# 25679  https://api.spotify.com/v1/audio-analysis/1tzc...      74813.0
# 25680  https://api.spotify.com/v1/audio-analysis/5jeZ...     731012.0
# 25681  https://api.spotify.com/v1/audio-analysis/331B...     299572.0
#
#        time_signature  success
# 0                 3.0      0.0
# 1                 5.0      0.0
# 2                 4.0      0.0
# 3                 4.0      0.0
# 4                 4.0      0.0
# ...               ...      ...
# 25677             4.0      0.0
# 25678             4.0      0.0
# 25679             4.0      0.0
# 25680             3.0      0.0
# 25681             4.0      0.0
#
# [25682 rows x 19 columns]

# %%
audio_df.to_csv('25682_random_songs_with_audio_features.csv', encoding='utf-8', index=False)
