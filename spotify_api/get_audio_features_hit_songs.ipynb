# %%
import numpy as np
import pandas as pd
import json
import os

pd.set_option("max_rows", 10)

# %%
# Reading Spotify web API credentials from settings.env hidden file

with open('settings.env') as f:
    env_vars = json.loads(f.read())

# Set environment variables
os.environ['SPOTIPY_CLIENT_ID'] = env_vars['SPOTIPY_CLIENT_ID']
os.environ['SPOTIPY_CLIENT_SECRET'] = env_vars['SPOTIPY_CLIENT_SECRET']

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

# %%
df = pd.read_csv('../web_scraping/weekly_hot100_1962-2020.csv')

# %%
# Let's use only tracks from year 2000 or later

df = df[df['year'] >= 2000]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         year          artist                          title
# 0       2000     SON BY FOUR  Purest Of Pain (A Puro Dolor)
# 1       2000    MARC ANTHONY                 You Sang To Me
# 2       2000      FAITH HILL                        Breathe
# 3       2000  JO DEE MESSINA                 That's The Way
# 4       2000    TONI BRAXTON         Just Be A Man About It
# ...      ...             ...                            ...
# 106895  2020          HALSEY              You Should Be Sad
# 106896  2020        LIL BABY                           Woah
# 106897  2020   TREVOR DANIEL                        Falling
# 106898  2020           LIZZO                    Truth Hurts
# 106899  2020    LIL UZI VERT            Futsal Shuffle 2020
#
# [106900 rows x 3 columns]

# %%
df[df.duplicated(['artist', 'title'])].shape
# Out:
# (94, 4)

# %%
df.drop_duplicates(subset=['artist', 'title'], inplace=True)

# %%
df.isnull().sum()
# Out:
# year      0
# artist    0
# title     0
# dtype: int64

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       year                                       artist  \
# 0     2000                                  SON BY FOUR
# 1     2000                                 MARC ANTHONY
# 2     2000                                   FAITH HILL
# 3     2000                               JO DEE MESSINA
# 4     2000                                 TONI BRAXTON
# ...    ...                                          ...
# 8590  2020             MIGOS, YOUNG THUG & TRAVIS SCOTT
# 8591  2020  A BOOGIE WIT DA HOODIE featuring YOUNG THUG
# 8592  2020      A BOOGIE WIT DA HOODIE featuring DABABY
# 8593  2020                       A BOOGIE WIT DA HOODIE
# 8594  2020                                JUSTIN BIEBER
#
#                               title
# 0     Purest Of Pain (A Puro Dolor)
# 1                    You Sang To Me
# 2                           Breathe
# 3                    That's The Way
# 4            Just Be A Man About It
# ...                             ...
# 8590            g n f (Give No Fxk)
# 8591              Might Not Give Up
# 8592                          Stain
# 8593                      Thug Love
# 8594                 Come Around Me
#
# [8595 rows x 3 columns]

# %%
# Cleaning artist and title names to avoid 'NaN'

import re

title = df['title'].tolist()
title_match = ['\'',
               '\s\(.*$']
title = [re.sub('|'.join(title_match), '', i) for i in title]

artist = df['artist'].tolist()
artist_match = ['\sFeaturing.*$',
                '\sfeaturing.*$',
                '\sFeauring.*$',
                '\s\(Featuring.*$',
                '\s\(With.*$',
                '\s\(Duet.*$',
                '\sIntroducing.*$',
                '\s\"Fenderella\"',
                'The West Coast Rap All-Stars',
                '\sVs.*$',
                '\sX\s.*$',
                '\sx\s.*$',
                '\sWith\s.*$',
                '\swith\s.*$',
                '\sPresents.*$',
                '\sPresents.*$',
                '\s&\s.*$',
                ',.*$',
                '\'']

artist = [re.sub('|'.join(artist_match), '', i) for i in artist]

# %%
df['artist'] = artist
df['title'] = title

# %%
df
# Out:
#       year                  artist                   title
# 0     2000             SON BY FOUR          Purest Of Pain
# 1     2000            MARC ANTHONY          You Sang To Me
# 2     2000              FAITH HILL                 Breathe
# 3     2000          JO DEE MESSINA           Thats The Way
# 4     2000            TONI BRAXTON  Just Be A Man About It
# ...    ...                     ...                     ...
# 8590  2020                   MIGOS                   g n f
# 8591  2020  A BOOGIE WIT DA HOODIE       Might Not Give Up
# 8592  2020  A BOOGIE WIT DA HOODIE                   Stain
# 8593  2020  A BOOGIE WIT DA HOODIE               Thug Love
# 8594  2020           JUSTIN BIEBER          Come Around Me
#
# [8595 rows x 3 columns]

# %%
track_id_list = []

for i in range(0,len(df['artist'])):
    search = sp.search(q='artist:' + df['artist'][i] + ' track:' + df['title'][i], type='track')
    if (search['tracks']['items'] == []):
         track_id_list.append(np.nan)
    else:
        track_id = search['tracks']['items'][0]['id']
        track_id_list.append(track_id)

# %%
df['track_id'] = track_id_list

# %%
df.isnull().sum()
# Out:
# year          0
# artist        0
# title         0
# track_id    507
# dtype: int64

# %%
df[df['track_id'].isnull()]
# Out:
#       year            artist                title track_id
# 8     2000              PINK           Most Girls      NaN
# 18    2000      SOULDECISION                Faded      NaN
# 28    2000            BB MAK            Back Here      NaN
# 35    2000       LIL BOW WOW       Bounce With Me      NaN
# 54    2000   ERIC HEATHERLEY  Flowers In The Wall      NaN
# ...    ...               ...                  ...      ...
# 8286  2020        JHENE AIKO          Pussy Fairy      NaN
# 8323  2020         SAM SMITH             Im Ready      NaN
# 8356  2020  KELSEY BALLERINI       the other girl      NaN
# 8494  2020      GARTH BROOKS             Dive Bar      NaN
# 8511  2020       JOHN LEGEND           Happy Xmas      NaN
#
# [507 rows x 4 columns]

# %%
# Removing rows with NaN in 'track_id'
df.dropna(inplace=True)

# %%
df[df['track_id'].duplicated()]
# Out:
#       year                 artist                title                track_id
# 104   2000              NINE DAYS           Absolutely  3mNecsYFb6LQg7822DPXCP
# 107   2000  RED HOT CHILI PEPPERS      Californication  48UPSzbZjgc449aqz8bxox
# 109   2000               LIL ZANE            Callin Me  0io6VQqmCT8Yz1faAqBUFh
# 110   2000                    MYA       Case Of The Ex  1ak0S3NhwWrUgNlQhJ1412
# 112   2000                  CREED  With Arms Open Wide  0eKyHwckh9vQb8ncZ2DXCs
# ...    ...                    ...                  ...                     ...
# 7878  2020               ARCANGEL        Sigues Con El  4Pu0a2TuHOYtI4CCE3HEXI
# 7999  2020               DJ SNAKE         Loco Contigo  6osaMSJh9NguagEDQcZaKx
# 8002  2020                 DaBABY                 Suge  2gwkD6igEhQbDQegRCcdoB
# 8015  2020                  GUNNA               Skybox  7GwYENSg87oERcW0Wacd6m
# 8067  2020                LIL NAS                Rodeo  4ak7xjvBeBOcJGWFDX9w5n
#
# [230 rows x 4 columns]

# %%
# Remove duplicates
df.drop_duplicates(subset=['track_id'], inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       year                  artist                   title  \
# 0     2000             SON BY FOUR          Purest Of Pain
# 1     2000            MARC ANTHONY          You Sang To Me
# 2     2000              FAITH HILL                 Breathe
# 3     2000          JO DEE MESSINA           Thats The Way
# 4     2000            TONI BRAXTON  Just Be A Man About It
# ...    ...                     ...                     ...
# 7853  2020                   MIGOS                   g n f
# 7854  2020  A BOOGIE WIT DA HOODIE       Might Not Give Up
# 7855  2020  A BOOGIE WIT DA HOODIE                   Stain
# 7856  2020  A BOOGIE WIT DA HOODIE               Thug Love
# 7857  2020           JUSTIN BIEBER          Come Around Me
#
#                     track_id
# 0     1MOqMyQ7CULmWWjovkFY5B
# 1     2dwhMQsFeHr2S787WxqAqW
# 2     3y4LxiYMgDl4RethdzpmNe
# 3     296XGtH5MeGisqD3uAz6Q6
# 4     6kD36kVRn5leDDbjXpHQY0
# ...                      ...
# 7853  6ZelF5APDN5r6XnFqcnvWR
# 7854  0bo4hZZV4aYI4EEh1IpDNa
# 7855  5ipk9bW6E344oWoylOOm82
# 7856  3bhvpwuvTXpoQMI3l41NQ0
# 7857  2o9LAypwGH4ctV0i9boo6d
#
# [7858 rows x 4 columns]

# %%
df.to_csv('hot100.csv', encoding='utf-8', index=False)

# %%
df = pd.read_csv('hot100.csv')

# %%
df
# Out:
#       year                  artist                   title  \
# 0     2000             SON BY FOUR          Purest Of Pain
# 1     2000            MARC ANTHONY          You Sang To Me
# 2     2000              FAITH HILL                 Breathe
# 3     2000          JO DEE MESSINA           Thats The Way
# 4     2000            TONI BRAXTON  Just Be A Man About It
# ...    ...                     ...                     ...
# 8083  2020                   MIGOS                   g n f
# 8084  2020  A BOOGIE WIT DA HOODIE       Might Not Give Up
# 8085  2020  A BOOGIE WIT DA HOODIE                   Stain
# 8086  2020  A BOOGIE WIT DA HOODIE               Thug Love
# 8087  2020           JUSTIN BIEBER          Come Around Me
#
#                     track_id
# 0     1MOqMyQ7CULmWWjovkFY5B
# 1     2dwhMQsFeHr2S787WxqAqW
# 2     3y4LxiYMgDl4RethdzpmNe
# 3     296XGtH5MeGisqD3uAz6Q6
# 4     6kD36kVRn5leDDbjXpHQY0
# ...                      ...
# 8083  6ZelF5APDN5r6XnFqcnvWR
# 8084  0bo4hZZV4aYI4EEh1IpDNa
# 8085  5ipk9bW6E344oWoylOOm82
# 8086  3bhvpwuvTXpoQMI3l41NQ0
# 8087  2o9LAypwGH4ctV0i9boo6d
#
# [8088 rows x 4 columns]

# %%
# Get audio_features

audio = [sp.audio_features(x) for x in df['track_id']]

# %%
audio_df = pd.DataFrame()

empty_row = {'danceability': np.nan,
 'energy': np.nan,
 'key': np.nan,
 'loudness': np.nan,
 'mode': np.nan,
 'speechiness': np.nan,
 'acousticness': np.nan,
 'instrumentalness': np.nan,
 'liveness': np.nan,
 'valence': np.nan,
 'tempo': np.nan,
 'type': np.nan,
 'id': np.nan,
 'uri': np.nan,
 'track_href': np.nan,
 'analysis_url': np.nan,
 'duration_ms': np.nan,
 'time_signature': np.nan}

for i in range(0,len(df['track_id'])):
    if type(audio[i][0]) != type(None):
        audio_df = audio_df.append(pd.json_normalize(audio[i][0]))
    else:
        audio_df = audio_df.append(pd.json_normalize(empty_row))

# %%
audio_df.reset_index(drop=True, inplace=True)

# %%
audio_df
# Out:
#       danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0            0.565   0.547   0.0    -7.722   1.0       0.0347        0.5790
# 1            0.578   0.894  10.0    -5.420   1.0       0.0296        0.0103
# 2            0.529   0.496   7.0    -9.007   1.0       0.0290        0.1730
# 3            0.488   0.923   2.0    -3.697   1.0       0.1030        0.1290
# 4            0.753   0.450   9.0    -6.909   1.0       0.0924        0.2740
# ...            ...     ...   ...       ...   ...          ...           ...
# 8083         0.904   0.627   1.0    -5.608   1.0       0.2220        0.0303
# 8084         0.687   0.592   2.0    -6.378   1.0       0.2250        0.2030
# 8085         0.816   0.754   8.0    -3.911   1.0       0.3880        0.0117
# 8086         0.543   0.643   5.0    -4.707   0.0       0.2880        0.4270
# 8087         0.648   0.681   2.0    -8.389   0.0       0.0378        0.2630
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.1940    0.252   75.018  audio_features
# 1             0.000003    0.2160    0.741  165.980  audio_features
# 2             0.000000    0.2510    0.278  136.859  audio_features
# 3             0.000000    0.1580    0.818  183.891  audio_features
# 4             0.000002    0.3210    0.560  109.405  audio_features
# ...                ...       ...      ...      ...             ...
# 8083          0.000006    0.0923    0.236  145.976  audio_features
# 8084          0.000000    0.2790    0.245  178.830  audio_features
# 8085          0.000000    0.1290    0.604  159.073  audio_features
# 8086          0.000000    0.1740    0.326  178.105  audio_features
# 8087          0.007830    0.0971    0.767  157.941  audio_features
#
#                           id                                   uri  \
# 0     1MOqMyQ7CULmWWjovkFY5B  spotify:track:1MOqMyQ7CULmWWjovkFY5B
# 1     2dwhMQsFeHr2S787WxqAqW  spotify:track:2dwhMQsFeHr2S787WxqAqW
# 2     3y4LxiYMgDl4RethdzpmNe  spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3     296XGtH5MeGisqD3uAz6Q6  spotify:track:296XGtH5MeGisqD3uAz6Q6
# 4     6kD36kVRn5leDDbjXpHQY0  spotify:track:6kD36kVRn5leDDbjXpHQY0
# ...                      ...                                   ...
# 8083  6ZelF5APDN5r6XnFqcnvWR  spotify:track:6ZelF5APDN5r6XnFqcnvWR
# 8084  0bo4hZZV4aYI4EEh1IpDNa  spotify:track:0bo4hZZV4aYI4EEh1IpDNa
# 8085  5ipk9bW6E344oWoylOOm82  spotify:track:5ipk9bW6E344oWoylOOm82
# 8086  3bhvpwuvTXpoQMI3l41NQ0  spotify:track:3bhvpwuvTXpoQMI3l41NQ0
# 8087  2o9LAypwGH4ctV0i9boo6d  spotify:track:2o9LAypwGH4ctV0i9boo6d
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1MOqMyQ7CULm...
# 1     https://api.spotify.com/v1/tracks/2dwhMQsFeHr2...
# 2     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3     https://api.spotify.com/v1/tracks/296XGtH5MeGi...
# 4     https://api.spotify.com/v1/tracks/6kD36kVRn5le...
# ...                                                 ...
# 8083  https://api.spotify.com/v1/tracks/6ZelF5APDN5r...
# 8084  https://api.spotify.com/v1/tracks/0bo4hZZV4aYI...
# 8085  https://api.spotify.com/v1/tracks/5ipk9bW6E344...
# 8086  https://api.spotify.com/v1/tracks/3bhvpwuvTXpo...
# 8087  https://api.spotify.com/v1/tracks/2o9LAypwGH4c...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1MOq...     209320.0
# 1     https://api.spotify.com/v1/audio-analysis/2dwh...     347107.0
# 2     https://api.spotify.com/v1/audio-analysis/3y4L...     250547.0
# 3     https://api.spotify.com/v1/audio-analysis/296X...     202253.0
# 4     https://api.spotify.com/v1/audio-analysis/6kD3...     288933.0
# ...                                                 ...          ...
# 8083  https://api.spotify.com/v1/audio-analysis/6Zel...     224243.0
# 8084  https://api.spotify.com/v1/audio-analysis/0bo4...     225266.0
# 8085  https://api.spotify.com/v1/audio-analysis/5ipk...     175128.0
# 8086  https://api.spotify.com/v1/audio-analysis/3bhv...     181744.0
# 8087  https://api.spotify.com/v1/audio-analysis/2o9L...     200773.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 8083             4.0
# 8084             4.0
# 8085             4.0
# 8086             4.0
# 8087             4.0
#
# [8088 rows x 18 columns]

# %%
# Merging both dataframes

df_audio = df.merge(audio_df, left_index=True, right_index=True, how='outer')

# %%
df_audio['success'] = 1.0

# %%
df_audio
# Out:
#       year                  artist                   title  \
# 0     2000             SON BY FOUR          Purest Of Pain
# 1     2000            MARC ANTHONY          You Sang To Me
# 2     2000              FAITH HILL                 Breathe
# 3     2000          JO DEE MESSINA           Thats The Way
# 4     2000            TONI BRAXTON  Just Be A Man About It
# ...    ...                     ...                     ...
# 8083  2020                   MIGOS                   g n f
# 8084  2020  A BOOGIE WIT DA HOODIE       Might Not Give Up
# 8085  2020  A BOOGIE WIT DA HOODIE                   Stain
# 8086  2020  A BOOGIE WIT DA HOODIE               Thug Love
# 8087  2020           JUSTIN BIEBER          Come Around Me
#
#                     track_id  danceability  energy   key  loudness  mode  \
# 0     1MOqMyQ7CULmWWjovkFY5B         0.565   0.547   0.0    -7.722   1.0
# 1     2dwhMQsFeHr2S787WxqAqW         0.578   0.894  10.0    -5.420   1.0
# 2     3y4LxiYMgDl4RethdzpmNe         0.529   0.496   7.0    -9.007   1.0
# 3     296XGtH5MeGisqD3uAz6Q6         0.488   0.923   2.0    -3.697   1.0
# 4     6kD36kVRn5leDDbjXpHQY0         0.753   0.450   9.0    -6.909   1.0
# ...                      ...           ...     ...   ...       ...   ...
# 8083  6ZelF5APDN5r6XnFqcnvWR         0.904   0.627   1.0    -5.608   1.0
# 8084  0bo4hZZV4aYI4EEh1IpDNa         0.687   0.592   2.0    -6.378   1.0
# 8085  5ipk9bW6E344oWoylOOm82         0.816   0.754   8.0    -3.911   1.0
# 8086  3bhvpwuvTXpoQMI3l41NQ0         0.543   0.643   5.0    -4.707   0.0
# 8087  2o9LAypwGH4ctV0i9boo6d         0.648   0.681   2.0    -8.389   0.0
#
#       speechiness  ...  valence    tempo            type  \
# 0          0.0347  ...    0.252   75.018  audio_features
# 1          0.0296  ...    0.741  165.980  audio_features
# 2          0.0290  ...    0.278  136.859  audio_features
# 3          0.1030  ...    0.818  183.891  audio_features
# 4          0.0924  ...    0.560  109.405  audio_features
# ...           ...  ...      ...      ...             ...
# 8083       0.2220  ...    0.236  145.976  audio_features
# 8084       0.2250  ...    0.245  178.830  audio_features
# 8085       0.3880  ...    0.604  159.073  audio_features
# 8086       0.2880  ...    0.326  178.105  audio_features
# 8087       0.0378  ...    0.767  157.941  audio_features
#
#                           id                                   uri  \
# 0     1MOqMyQ7CULmWWjovkFY5B  spotify:track:1MOqMyQ7CULmWWjovkFY5B
# 1     2dwhMQsFeHr2S787WxqAqW  spotify:track:2dwhMQsFeHr2S787WxqAqW
# 2     3y4LxiYMgDl4RethdzpmNe  spotify:track:3y4LxiYMgDl4RethdzpmNe
# 3     296XGtH5MeGisqD3uAz6Q6  spotify:track:296XGtH5MeGisqD3uAz6Q6
# 4     6kD36kVRn5leDDbjXpHQY0  spotify:track:6kD36kVRn5leDDbjXpHQY0
# ...                      ...                                   ...
# 8083  6ZelF5APDN5r6XnFqcnvWR  spotify:track:6ZelF5APDN5r6XnFqcnvWR
# 8084  0bo4hZZV4aYI4EEh1IpDNa  spotify:track:0bo4hZZV4aYI4EEh1IpDNa
# 8085  5ipk9bW6E344oWoylOOm82  spotify:track:5ipk9bW6E344oWoylOOm82
# 8086  3bhvpwuvTXpoQMI3l41NQ0  spotify:track:3bhvpwuvTXpoQMI3l41NQ0
# 8087  2o9LAypwGH4ctV0i9boo6d  spotify:track:2o9LAypwGH4ctV0i9boo6d
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/1MOqMyQ7CULm...
# 1     https://api.spotify.com/v1/tracks/2dwhMQsFeHr2...
# 2     https://api.spotify.com/v1/tracks/3y4LxiYMgDl4...
# 3     https://api.spotify.com/v1/tracks/296XGtH5MeGi...
# 4     https://api.spotify.com/v1/tracks/6kD36kVRn5le...
# ...                                                 ...
# 8083  https://api.spotify.com/v1/tracks/6ZelF5APDN5r...
# 8084  https://api.spotify.com/v1/tracks/0bo4hZZV4aYI...
# 8085  https://api.spotify.com/v1/tracks/5ipk9bW6E344...
# 8086  https://api.spotify.com/v1/tracks/3bhvpwuvTXpo...
# 8087  https://api.spotify.com/v1/tracks/2o9LAypwGH4c...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/1MOq...    209320.0
# 1     https://api.spotify.com/v1/audio-analysis/2dwh...    347107.0
# 2     https://api.spotify.com/v1/audio-analysis/3y4L...    250547.0
# 3     https://api.spotify.com/v1/audio-analysis/296X...    202253.0
# 4     https://api.spotify.com/v1/audio-analysis/6kD3...    288933.0
# ...                                                 ...         ...
# 8083  https://api.spotify.com/v1/audio-analysis/6Zel...    224243.0
# 8084  https://api.spotify.com/v1/audio-analysis/0bo4...    225266.0
# 8085  https://api.spotify.com/v1/audio-analysis/5ipk...    175128.0
# 8086  https://api.spotify.com/v1/audio-analysis/3bhv...    181744.0
# 8087  https://api.spotify.com/v1/audio-analysis/2o9L...    200773.0
#
#      time_signature success
# 0               4.0     1.0
# 1               4.0     1.0
# 2               4.0     1.0
# 3               4.0     1.0
# 4               4.0     1.0
# ...             ...     ...
# 8083            4.0     1.0
# 8084            4.0     1.0
# 8085            4.0     1.0
# 8086            4.0     1.0
# 8087            4.0     1.0
#
# [8088 rows x 23 columns]

# %%
df_audio.to_csv('hot100_with_audio_features.csv', encoding='utf-8', index=False)
